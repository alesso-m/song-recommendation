# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time
import json
from pathlib import Path
from flatten_json import flatten
from urllib.error import HTTPError
import time, sys
from IPython.display import clear_output
from sklearn.neighbors import NearestNeighbors

# %%
client_id = '#################'
client_secret = '####################'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    results = sp.user_playlist(user, playlist_id, fields="tracks,next")
    tracks = results['tracks']
    for i in range(0, len(tracks['items'])):
        ids.append(tracks['items'][i]['track']['id'])

    while tracks['next']:
        tracks = sp.next(tracks)
    
    for i in range(0, len(tracks['items'])):
        ids.append(tracks['items'][i]['track']['id'])
        
    return ids
        
user_ids = getTrackIDs('ethan8chang', '0mbobnEpYbg1ONLafaWWR3')

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']
  key = features[0]['key']
  mode = features[0]['mode']
  valence = features[0]['valence']

  track = [name, album, artist, release_date, length, popularity, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature]
  return track

# %%
def getGenres(song_features): 
    genres = []
    for i in range (0, len(song_features)):
        result = sp.search(song_features['artist'][i])
        track = result['tracks']['items'][0]

        artist = sp.artist(track["artists"][0]["external_urls"]["spotify"])
        genres.append(artist['genres'])
        
    return genres

# %%
def createFullPlaylistDf(track_features):
    all_tracks = []
    for i in range(len(track_features)):
      track = getTrackFeatures(track_features[i])
      all_tracks.append(track)
    
    # create dataset
    df = pd.DataFrame(all_tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'])
    
    genres = getGenres(df)
    
    df['genres'] = genres
    
    return df

# %%
user_playlist = createFullPlaylistDf(user_ids)
user_playlist
# Out:
#                  name                album                  artist  \
# 0            Syphilis  Death Race For Love              Juice WRLD
# 1       God's Warrior        God's Warrior            Tee Grizzley
# 2          YuNg BrAtZ              Revenge            XXXTENTACION
# 3               Shots    We Love You Tecca               Lil Tecca
# 4    Carbonated Water     Carbonated Water  Ski Mask The Slump God
# ..                ...                  ...                     ...
# 111         No Chains            No Chains                      KB
# 112        Chanel Bag           Chanel Bag                KillBunk
# 113    Do You Feel Me           DC Fridays              DC The Don
# 114     Daij Is Drunk        Daij Is Drunk              DC The Don
# 115       Elimination                   23            JayDaYoungan
#
#     release_date  length  popularity  danceability  energy  key  loudness  \
# 0     2019-03-08  131761          65         0.782   0.659    1    -3.103
# 1     2019-04-18  167704          42         0.803   0.689    1    -5.318
# 2     2017-05-16  101851          74         0.755   0.695    9    -5.963
# 3     2019-08-30  109373           0         0.829   0.582    7    -5.721
# 4     2019-10-31  141040          63         0.938   0.559   10    -6.734
# ..           ...     ...         ...           ...     ...  ...       ...
# 111   2018-04-18  222651           0         0.676   0.815    1    -3.427
# 112   2020-10-31  158667          72         0.773   0.614   11    -5.490
# 113   2019-12-20  190824          30         0.732   0.543   11   -10.747
# 114   2021-05-07  134011          49         0.767   0.508    9    -7.850
# 115   2018-07-15  154560          64         0.755   0.517    4    -9.804
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0       1       0.2480       0.06960          0.000000    0.1680    0.336
# 1       0       0.4030       0.21500          0.000000    0.2830    0.684
# 2       1       0.2600       0.01790          0.000000    0.1070    0.493
# 3       0       0.0415       0.52500          0.000000    0.0759    0.510
# 4       1       0.3120       0.05460          0.000000    0.1570    0.760
# ..    ...          ...           ...               ...       ...      ...
# 111     1       0.2780       0.01520          0.000004    0.1070    0.591
# 112     0       0.0776       0.06780          0.000000    0.0873    0.700
# 113     1       0.2400       0.00849          0.000194    0.1080    0.523
# 114     1       0.3480       0.13500          0.000000    0.1190    0.452
# 115     0       0.0751       0.75400          0.000000    0.1270    0.699
#
#        tempo  time_signature  \
# 0    148.030               4
# 1    157.517               4
# 2    128.063               4
# 3    108.028               4
# 4    119.901               4
# ..       ...             ...
# 111  162.054               4
# 112  115.015               4
# 113  155.924               4
# 114  159.806               4
# 115  129.027               4
#
#                                                 genres
# 0                           [chicago rap, melodic rap]
# 1    [detroit hip hop, detroit trap, hip hop, rap, ...
# 2                             [emo rap, miami hip hop]
# 3                             [melodic rap, rap, trap]
# 4                 [miami hip hop, underground hip hop]
# ..                                                 ...
# 111                [christian hip hop, christian trap]
# 112                                          [sad rap]
# 113                [melodic rap, meme rap, vapor trap]
# 114                [melodic rap, meme rap, vapor trap]
# 115              [melodic rap, southern hip hop, trap]
#
# [116 rows x 19 columns]

# %%
def update_progress(progress):
    bar_length = 20
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1

    block = int(round(bar_length * progress))

    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)

# %%
def getTrackDF(ids):
    # loop over track ids 
    tracks = []
    for i in range(len(ids)):
        try:
            track = getTrackFeatures(ids[i])
            tracks.append(track)
        except HTTPError as err:
            print(err.code)
        update_progress(i/len(ids))

    # create dataset
    df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'])
    return df

# %%
def getDatasetIDs(playlist_df):
    ids = []
    for i in range (0, playlist_df['track_uri'].count()-1):
        uri = playlist_df['track_uri'][i]
        shortened = uri[14:]
        ids.append(shortened)
    return ids

# %%
def import_json_playlist_x(local_path, x):
    p = Path(local_path)
    with p.open('r', encoding='utf-8') as f:
        data = json.loads(f.read())
    tracks_data = data['playlists']
    
    #make loop so that it loops through all playlists in the one instance
    first_playlist_tracks = tracks_data[0]['tracks']
    total_tracks_df = pd.DataFrame(first_playlist_tracks)
    

    for i in range (1, x):
        a_playlist_tracks = tracks_data[i]['tracks']
        a_playlist_df  = pd.DataFrame(a_playlist_tracks)
    
        
        total_tracks_df = total_tracks_df.append(a_playlist_df, ignore_index = True)

        
    total_tracks_df_ids = getDatasetIDs(total_tracks_df)
    total_tracks_df_ids_features = getTrackDF(total_tracks_df_ids)
    
    
    
    return total_tracks_df_ids_features

# %%
def add_genres(total_tracks_df_ids_features):
    genres = []
    for i in range (0, len(total_tracks_df_ids_features)):
        result = sp.search(total_tracks_df_ids_features['artist'][i])
        track = result['tracks']['items'][0]

        artist = sp.artist(track["artists"][0]["external_urls"]["spotify"])
        
        genres.append(artist['genres'])
        
        update_progress(i/len(total_tracks_df_ids_features))
        
    return genres

# %%
song_dataset = import_json_playlist_x(r'C:\Users\ecusa\OneDrive\Desktop\MPSD\mpd.slice.3000-3999.json', 5)
# Out:
# Progress: [####################] 99.7%

# %%
genres = add_genres(song_dataset)
genres
# Out:
# Progress: [####################] 99.7%
# [['belgian edm', 'edm', 'pop', 'pop dance', 'tropical house'],
#  ['neo soul', 'pop', 'pop soul', 'r&b', 'urban contemporary'],
#  ['deep tropical house', 'gauze pop'],
#  ['big room',
#   'brostep',
#   'dance pop',
#   'dutch edm',
#   'edm',
#   'house',
#   'pop',
#   'pop dance',
#   'slap house',
#   'trance',
#   'tropical house'],
#  ['alt z', 'australian pop', 'nz pop'],
#  ['neo soul', 'r&b'],
#  ['australian dance', 'melbourne bounce'],
#  ['brazilian edm', 'complextro'],
#  ['edm', 'pop', 'pop dance', 'tropical house'],
#  ['contemporary country', 'country road', 'modern country rock'],
#  ['german dance', 'slap house'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['dance pop', 'edm', 'electropop', 'pop', 'pop dance', 'tropical house'],
#  ['deep house',
#   'deep tropical house',
#   'electra',
#   'house',
#   'pop dance',
#   'progressive house',
#   'swiss pop',
#   'tropical house'],
#  ['alt z',
#   'electropop',
#   'indie cafe pop',
#   'indie electropop',
#   'indie poptimism',
#   'pop edm',
#   'post-teen pop'],
#  ['deep house',
#   'deep tropical house',
#   'electra',
#   'house',
#   'pop dance',
#   'progressive house',
#   'swiss pop',
#   'tropical house'],
#  ['afrofuturism',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['afrofuturism',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['afrofuturism',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['afrofuturism',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['atl hip hop', 'dirty south rap', 'hip hop', 'rap', 'southern hip hop'],
#  ['british soul', 'indie soul', 'neo soul', 'pop soul', 'soul'],
#  ['british soul', 'indie soul', 'neo soul', 'pop soul', 'soul'],
#  ['indie cafe pop', 'pop', 'post-teen pop'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['neo soul', 'r&b'],
#  ['dance pop', 'pop', 'pop rap'],
#  ['funk',
#   'hip hop',
#   'hip pop',
#   'neo soul',
#   'quiet storm',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['funk',
#   'hip hop',
#   'hip pop',
#   'neo soul',
#   'quiet storm',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['funk',
#   'hip hop',
#   'hip pop',
#   'neo soul',
#   'quiet storm',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['funk',
#   'hip hop',
#   'hip pop',
#   'neo soul',
#   'quiet storm',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['funk',
#   'hip hop',
#   'hip pop',
#   'neo soul',
#   'quiet storm',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'],
#  ['neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'],
#  ['hip pop', 'neo soul', 'quiet storm', 'r&b', 'urban contemporary'],
#  ['hip pop', 'neo soul', 'quiet storm', 'r&b', 'urban contemporary'],
#  ['alternative hip hop'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['bow pop', 'pop violin'],
#  ['modern rock', 'pop rap'],
#  ['modern rock', 'pop rap'],
#  ['south african pop', 'south african pop dance'],
#  ['complextro',
#   'dance pop',
#   'edm',
#   'electro house',
#   'electropop',
#   'german techno',
#   'pop',
#   'pop dance',
#   'post-teen pop',
#   'tropical house'],
#  ['latin', 'latin pop', 'puerto rican pop'],
#  ['dance pop', 'edm', 'electropop', 'pop', 'pop dance', 'tropical house'],
#  ['italian hip hop', 'italian pop', 'r&b italiano', 'trap italiana'],
#  ['pop', 'uk pop'],
#  ['modern rock', 'rock'],
#  ['dance pop',
#   'edm',
#   'electro house',
#   'pop',
#   'pop dance',
#   'progressive electro house',
#   'tropical house'],
#  ['dance pop', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'queens hip hop'],
#  ['indie folk', 'indie pop', 'stomp and holler'],
#  ['nashville indie'],
#  ['nashville indie'],
#  ['shimmer pop', 'shiver pop'],
#  ['neo mellow', 'pop', 'pop rock', 'singer-songwriter'],
#  ['bubblegrunge', 'chicago indie', 'indie pop', 'pop'],
#  ['alternative hip hop'],
#  ['alternative dance', 'australian indie', 'indie rock', 'modern rock'],
#  ['brostep',
#   'dance pop',
#   'edm',
#   'pop',
#   'pop dance',
#   'progressive electro house'],
#  ['alternative dance',
#   'art pop',
#   'chillwave',
#   'dream pop',
#   'electronica',
#   'electropop',
#   'modern dream pop',
#   'neo-synthpop',
#   'new rave'],
#  ['alternative dance',
#   'art pop',
#   'chillwave',
#   'dream pop',
#   'electropop',
#   'indie pop',
#   'indietronica',
#   'metropopolis',
#   'new rave',
#   'shimmer pop'],
#  ['art pop',
#   'canadian electropop',
#   'chillwave',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'grave wave',
#   'hyperpop',
#   'indietronica',
#   'metropopolis',
#   'pop'],
#  [],
#  ['indie soul', 'uk alternative pop'],
#  ['chillwave', 'metropopolis', 'shimmer pop'],
#  ['acoustic pop',
#   'alt z',
#   'electropop',
#   'indie cafe pop',
#   'indie poptimism',
#   'neo mellow',
#   'neo-singer-songwriter',
#   'pop',
#   'pop rock',
#   'post-teen pop',
#   'uk pop',
#   'viral pop'],
#  ['indie cafe pop', 'pop', 'post-teen pop'],
#  ['indie cafe pop', 'pop', 'post-teen pop'],
#  ['edm', 'electro house', 'pop dance'],
#  ['instrumental grime', 'purple sound'],
#  ['baroque pop',
#   'indie pop',
#   'indie poptimism',
#   'indie rock',
#   'indietronica',
#   'modern rock',
#   'piano rock',
#   'shimmer pop',
#   'stomp and holler'],
#  ['indie pop',
#   'indie poptimism',
#   'indiecoustica',
#   'modern alternative rock',
#   'modern rock',
#   'piano rock',
#   'pop rock',
#   'stomp and holler'],
#  ['stomp and holler'],
#  ['shimmer pop', 'shiver pop'],
#  ['modern rock', 'rock'],
#  ['shimmer pop', 'shiver pop'],
#  ['pop edm'],
#  ['pop edm'],
#  ['redneck'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['shimmer pop', 'shiver pop'],
#  ['british post-rock', 'chamber psych', 'cosmic post-rock', 'post-rock'],
#  ['british post-rock', 'chamber psych', 'cosmic post-rock', 'post-rock'],
#  ['pop', 'post-teen pop'],
#  ['alternative metal',
#   'alternative rock',
#   'grunge',
#   'permanent wave',
#   'pop rock',
#   'rock'],
#  ['art pop',
#   'british soul',
#   'dance pop',
#   'electropop',
#   'neo soul',
#   'pop',
#   'pop soul',
#   'tropical house'],
#  ['electronica', 'future garage', 'new rave'],
#  ['chillwave', 'electropop', 'greek indie', 'metropopolis'],
#  ['art pop', 'deep latin alternative'],
#  ['indie pop'],
#  ['indie pop'],
#  ['barbadian pop',
#   'dance pop',
#   'pop',
#   'pop rap',
#   'post-teen pop',
#   'urban contemporary'],
#  [],
#  ['indie folk', 'indie pop', 'stomp and holler'],
#  ['indie folk', 'indie pop', 'stomp and holler'],
#  ['canadian indie',
#   'indie pop',
#   'indie rock',
#   'modern rock',
#   'shimmer pop',
#   'stomp and holler',
#   'toronto indie'],
#  ['classic tollywood', 'filmi'],
#  ['hip pop', 'miami hip hop'],
#  ['dirty south rap', 'pop rap', 'southern hip hop'],
#  ['atl hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['oxford indie', 'stomp pop'],
#  ['hollywood', 'pop', 'post-teen pop', 'social media pop'],
#  ['acoustic pop',
#   'dance pop',
#   'lilith',
#   'neo mellow',
#   'pop',
#   'pop rock',
#   'post-teen pop'],
#  ['emo rap', 'miami hip hop'],
#  ['pop', 'post-teen pop'],
#  ['neo mellow', 'pop', 'pop rock', 'singer-songwriter'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['dance pop', 'pop', 'pop rap', 'r&b', 'rap'],
#  ['dutch trance', 'edm', 'pop dance', 'progressive house', 'trance'],
#  ['folk-pop', 'modern rock', 'pop', 'pop rock', 'stomp and holler'],
#  ['acoustic pop',
#   'folk',
#   'indie folk',
#   'indie pop',
#   'lilith',
#   'neo mellow',
#   'pop rock'],
#  ['edm', 'electro house', 'pop dance'],
#  ['boston indie', 'chamber pop'],
#  ['indie pop', 'indie rock', 'modern rock', 'pop rock', 'washington indie'],
#  ['a cappella'],
#  ['dance pop', 'neo mellow', 'pop', 'pop rock', 'post-teen pop', 'viral pop'],
#  ['indie folk', 'vapor soul'],
#  [],
#  [],
#  ['indie folk', 'indie pop', 'stomp and holler'],
#  ['boy band', 'dance pop', 'electropop', 'pop', 'post-teen pop'],
#  ['dance pop', 'pop', 'post-teen pop', 'uk pop'],
#  ['tropical house'],
#  ['australian indie'],
#  ['austindie'],
#  ['canadian contemporary r&b', 'folk-pop'],
#  ['pop', 'post-teen pop'],
#  ['pop', 'post-teen pop'],
#  ['pop', 'post-teen pop'],
#  [],
#  ['nashville indie'],
#  [],
#  ['folk-pop',
#   'modern rock',
#   'neo mellow',
#   'neo-singer-songwriter',
#   'pop',
#   'pop rock'],
#  [],
#  ['british folk',
#   'classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['french shoegaze',
#   'french synthpop',
#   'indietronica',
#   'metropopolis',
#   'neo-synthpop'],
#  [],
#  ['folk-pop',
#   'indie folk',
#   'indie pop',
#   'modern rock',
#   'new americana',
#   'pop rock',
#   'seattle indie',
#   'stomp and holler'],
#  ['folk-pop',
#   'indie folk',
#   'indie pop',
#   'modern rock',
#   'new americana',
#   'pop rock',
#   'seattle indie',
#   'stomp and holler'],
#  ['eau claire indie', 'indie folk', 'melancholia'],
#  [],
#  [],
#  ['electropop',
#   'indie pop',
#   'indie poptimism',
#   'indie rock',
#   'indietronica',
#   'la indie',
#   'modern alternative rock',
#   'modern rock',
#   'rock',
#   'shimmer pop'],
#  ['brostep',
#   'complextro',
#   'edm',
#   'electro house',
#   'moombahton',
#   'pop dance',
#   'progressive electro house'],
#  ['nyc pop'],
#  ['irish singer-songwriter', 'modern rock', 'pop'],
#  [],
#  ['alt z',
#   'electropop',
#   'indie cafe pop',
#   'indie electropop',
#   'indie poptimism',
#   'pop edm',
#   'post-teen pop'],
#  ['alternative metal', 'nu metal', 'rap metal', 'rock', 'sacramento indie'],
#  ['edm', 'pop', 'pop dance', 'tropical house'],
#  ['brostep',
#   'complextro',
#   'edm',
#   'electro house',
#   'moombahton',
#   'pop dance',
#   'progressive electro house'],
#  ['brostep',
#   'complextro',
#   'edm',
#   'electro house',
#   'moombahton',
#   'pop dance',
#   'progressive electro house'],
#  ['chamber pop',
#   'freak folk',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'seattle indie',
#   'stomp and holler'],
#  ['metropopolis', 'shimmer pop', 'tropical house'],
#  ['ninja'],
#  ['conscious hip hop', 'hip hop', 'north carolina hip hop', 'rap'],
#  ['gauze pop', 'indietronica', 'shiver pop'],
#  ['shiver pop'],
#  ['pop', 'uk pop'],
#  ['australian indie'],
#  [],
#  [],
#  ['american post-rock', 'compositional ambient', 'post-rock'],
#  ['alternative dance',
#   'art pop',
#   'chillwave',
#   'electronica',
#   'electropop',
#   'folktronica',
#   'indie rock',
#   'indie soul',
#   'indietronica',
#   'intelligent dance music',
#   'new rave'],
#  ['dance pop', 'edm', 'electronic trap', 'pop', 'pop dance', 'pop rap'],
#  ['la pop', 'pop', 'post-teen pop'],
#  ['australian indie folk', 'chamber pop'],
#  ['pop'],
#  ['gauze pop', 'progressive house', 'tropical house'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['neo mellow', 'pop', 'pop rock', 'singer-songwriter'],
#  ['modern rock'],
#  ['folk-pop', 'new americana', 'stomp and holler'],
#  ['brostep',
#   'complextro',
#   'edm',
#   'electro house',
#   'moombahton',
#   'pop dance',
#   'progressive electro house'],
#  ['downtempo bass', 'electra', 'vapor twitch'],
#  ['alternative dance',
#   'dance-punk',
#   'electronica',
#   'electropop',
#   'french indie pop',
#   'indie rock',
#   'indietronica',
#   'modern rock',
#   'new rave',
#   'socal pop punk'],
#  ['alt z', 'electropop', 'gauze pop', 'indie poptimism', 'pop'],
#  ['brooklyn indie',
#   'chamber pop',
#   'indie pop',
#   'shimmer pop',
#   'stomp and holler'],
#  ['arab electronic'],
#  ['la pop', 'pop', 'post-teen pop'],
#  ['edm',
#   'electro house',
#   'electronic trap',
#   'electropop',
#   'future bass',
#   'pop dance',
#   'pop edm',
#   'vapor twitch'],
#  ['art pop',
#   'british soul',
#   'dance pop',
#   'electropop',
#   'neo soul',
#   'pop',
#   'pop soul',
#   'tropical house'],
#  ['australian indie folk', 'indie folk', 'stomp and holler'],
#  ['chillwave'],
#  ['folk-pop', 'nz pop'],
#  ['british singer-songwriter',
#   'folk-pop',
#   'indie folk',
#   'neo mellow',
#   'stomp and holler'],
#  ['melancholia', 'stomp and flutter'],
#  ['indie rock', 'modern rock'],
#  ['folk-pop',
#   'indie anthem-folk',
#   'indie folk',
#   'stomp and flutter',
#   'stomp and holler',
#   'uk americana'],
#  ['dance pop',
#   'hip hop',
#   'pittsburgh rap',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  [],
#  ['alternative dance',
#   'art pop',
#   'chillwave',
#   'electronica',
#   'electropop',
#   'folktronica',
#   'indie rock',
#   'indie soul',
#   'indietronica',
#   'intelligent dance music',
#   'new rave'],
#  ['indie anthem-folk', 'indie folk', 'stomp and holler', 'york indie'],
#  ['icelandic indie',
#   'icelandic rock',
#   'modern alternative rock',
#   'modern rock'],
#  ['ambient folk', 'art pop', 'chamber pop', 'chamber psych', 'indie folk'],
#  [],
#  ['indie soul', 'neo soul'],
#  [],
#  ['electronic rock'],
#  ['edm',
#   'electro house',
#   'electronic trap',
#   'electropop',
#   'future bass',
#   'pop dance',
#   'pop edm',
#   'vapor twitch'],
#  ['indie rock', 'philly indie', 'shimmer pop'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['melodic rap', 'philly rap', 'rap', 'trap'],
#  ['electropop',
#   'indie pop',
#   'indie poptimism',
#   'indietronica',
#   'modern dream pop',
#   'vapor soul'],
#  ['canadian hip hop',
#   'deep underground hip hop',
#   'toronto rap',
#   'trap soul',
#   'underground hip hop'],
#  ['downtempo bass', 'electra', 'vapor twitch'],
#  ['electropop', 'indie poptimism', 'vapor soul', 'vapor twitch'],
#  ['gauze pop',
#   'indie electropop',
#   'indie pop',
#   'indie poptimism',
#   'shimmer pop',
#   'uk pop',
#   'vapor soul'],
#  ['indie pop',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'stomp and holler',
#   'swedish alternative rock'],
#  [],
#  ['ambient folk', 'indie cafe pop', 'indie folk'],
#  ['glam rock', 'mellow gold', 'piano rock', 'soft rock'],
#  ['shimmer pop'],
#  ['athens indie', 'folk-pop', 'indiecoustica', 'stomp and holler'],
#  ['classic persian pop'],
#  ['ohio hip hop', 'pop rap'],
#  ['vapor soul'],
#  ['electropop', 'pop'],
#  ['indie cafe pop', 'pop', 'post-teen pop'],
#  ['electropop', 'modern alternative rock', 'modern rock', 'pop'],
#  ['indie poptimism'],
#  ['australian indie folk', 'indie folk', 'stomp and holler'],
#  ['electropop',
#   'indie pop',
#   'indie poptimism',
#   'indietronica',
#   'modern dream pop',
#   'vapor soul'],
#  ['big room',
#   'brostep',
#   'dance pop',
#   'dutch edm',
#   'edm',
#   'house',
#   'pop',
#   'pop dance',
#   'slap house',
#   'trance',
#   'tropical house'],
#  ['dutch edm'],
#  ['meme rap'],
#  ['indie poptimism'],
#  ['art pop',
#   'electropop',
#   'etherpop',
#   'indie folk',
#   'indie pop',
#   'indie poptimism',
#   'indie rock'],
#  ['alternative r&b', 'chill r&b', 'indie r&b', 'pop', 'pop r&b', 'r&b'],
#  ['double drumming',
#   'indie pop',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop',
#   'pop rock',
#   'stomp and holler'],
#  ['dance pop', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'queens hip hop'],
#  ['art pop',
#   'baltimore indie',
#   'dream pop',
#   'indie pop',
#   'indie rock',
#   'modern dream pop'],
#  ['swedish alternative rock', 'swedish jazz', 'swedish pop'],
#  [],
#  ['electropop',
#   'indie pop',
#   'indie poptimism',
#   'indietronica',
#   'modern dream pop',
#   'vapor soul'],
#  ['electropop',
#   'indie pop',
#   'indie poptimism',
#   'indietronica',
#   'modern dream pop',
#   'vapor soul'],
#  ['dance pop', 'edm', 'pop dance', 'pop edm', 'slap house', 'tropical house'],
#  ['alt z',
#   'electropop',
#   'indie electropop',
#   'indie pop',
#   'indie poptimism',
#   'metropopolis',
#   'pop',
#   'vapor soul'],
#  [],
#  ['alt z',
#   'canadian pop',
#   'dance pop',
#   'electropop',
#   'indie cafe pop',
#   'pop',
#   'post-teen pop'],
#  [],
#  ['australian talent show'],
#  ['monterrey indie'],
#  ['gauze pop', 'shimmer pop'],
#  ['uk alternative pop'],
#  ['folk-pop', 'indie poptimism', 'pop rock', 'stomp and holler'],
#  ['vapor soul'],
#  ['ambient folk'],
#  ['pop rap'],
#  ['vapor pop'],
#  ['brooklyn indie', 'indie poptimism', 'metropopolis', 'shimmer pop'],
#  ['australian dance',
#   'australian electropop',
#   'australian indie',
#   'downtempo',
#   'edm'],
#  ['la indie'],
#  ['australian pop'],
#  ['future ambient'],
#  [],
#  ['indie folk',
#   'indie pop',
#   'indie poptimism',
#   'modern rock',
#   'nyc pop',
#   'stomp and holler',
#   'vapor soul'],
#  ['colombian pop', 'dance pop', 'latin', 'latin pop', 'pop'],
#  ['indie pop', 'oakland indie'],
#  ['vapor soul'],
#  ['indie anthem-folk',
#   'indie cafe pop',
#   'indie folk',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock'],
#  ['chill pop', 'indie electropop', 'indie poptimism', 'vapor soul'],
#  [],
#  ['electropop', 'tropical house', 'vapor soul'],
#  ['indie poptimism', 'modern rock', 'pop'],
#  ['boston folk',
#   'folk-pop',
#   'indie anthem-folk',
#   'indie folk',
#   'indiecoustica',
#   'new americana',
#   'stomp and holler'],
#  [],
#  ['dark trap', 'meme rap', 'underground hip hop', 'vapor trap'],
#  ['australian reggae fusion'],
#  ['indie anthem-folk'],
#  ['chillwave',
#   'downtempo',
#   'electronica',
#   'indietronica',
#   'intelligent dance music'],
#  ['ccm',
#   'christian alternative rock',
#   'christian indie',
#   'christian music',
#   'folk-pop',
#   'indiecoustica',
#   'neo mellow',
#   'pop rock',
#   'worship'],
#  ['icelandic folk', 'icelandic indie', 'icelandic pop', 'indie folk'],
#  ['alternative dance', 'aussietronica', 'nu disco'],
#  ['alternative dance',
#   'australian dance',
#   'filter house',
#   'indietronica',
#   'new rave',
#   'nu disco'],
#  ['atl hip hop', 'rap', 'trap'],
#  ['acoustic pop',
#   'indie anthem-folk',
#   'indie folk',
#   'indie poptimism',
#   'indiecoustica',
#   'neo mellow',
#   'pop rock'],
#  ['boston folk',
#   'folk-pop',
#   'indie anthem-folk',
#   'indie folk',
#   'indiecoustica',
#   'new americana',
#   'stomp and holler'],
#  ['indie folk',
#   'indie pop',
#   'indie poptimism',
#   'modern rock',
#   'nyc pop',
#   'stomp and holler',
#   'vapor soul'],
#  ['indie poptimism', 'indiecoustica', 'stomp and holler'],
#  ['underground hip hop'],
#  ['oc rap'],
#  ['alternative hip hop',
#   'boom bap',
#   'harlem hip hop',
#   'hip hop',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'underground hip hop'],
#  ['indie pop rap', 'pop rap'],
#  ['underground hip hop'],
#  ['hip hop', 'pittsburgh rap', 'rap'],
#  ['east coast reggae', 'jawaiian', 'reggae fusion', 'reggae rock'],
#  ['underground hip hop'],
#  ['underground hip hop'],
#  ['underground hip hop'],
#  ['underground hip hop'],
#  ['underground hip hop'],
#  ['electropop', 'pop', 'pop rap'],
#  ['deep new americana',
#   'indie folk',
#   'modern folk rock',
#   'modern rock',
#   'new americana',
#   'stomp and holler'],
#  ['indie pop rap', 'pop rap'],
#  ['ccm',
#   'christian alternative rock',
#   'christian music',
#   'world worship',
#   'worship'],
#  ['boy band', 'dance pop', 'pop', 'post-teen pop'],
#  ['hip hop', 'pittsburgh rap', 'rap'],
#  ['emo', 'pop punk'],
#  ['alternative r&b', 'indie r&b', 'memphis hip hop', 'underground hip hop'],
#  ['conscious hip hop', 'hip hop', 'rap', 'west coast rap'],
#  ['hip hop', 'rap', 'underground hip hop'],
#  ['north carolina hip hop', 'underground hip hop'],
#  ['alternative r&b', 'indie r&b', 'memphis hip hop', 'underground hip hop'],
#  ['alt z',
#   'electropop',
#   'escape room',
#   'hip pop',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop',
#   'rock'],
#  ['alternative r&b', 'indie r&b', 'memphis hip hop', 'underground hip hop'],
#  ['bass trap',
#   'brostep',
#   'edm',
#   'electro house',
#   'electronic trap',
#   'pop dance',
#   'vapor twitch'],
#  ['deep underground hip hop', 'milwaukee hip hop', 'underground hip hop'],
#  ['deep new americana',
#   'indie folk',
#   'modern rock',
#   'new americana',
#   'stomp and holler'],
#  ['charlotte nc indie',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'vapor soul'],
#  ['boston punk',
#   'boston rock',
#   'celtic punk',
#   'celtic rock',
#   'punk',
#   'skate punk'],
#  ['alternative metal',
#   'canadian pop punk',
#   'canadian punk',
#   'nu metal',
#   'pop punk',
#   'punk'],
#  ['background piano'],
#  ['deep new americana', 'portland indie'],
#  ['reggae rock'],
#  ['alternative metal',
#   'canadian pop punk',
#   'canadian punk',
#   'nu metal',
#   'pop punk',
#   'punk'],
#  ['deep new americana', 'portland indie'],
#  ['bow pop', 'celtic punk', 'celtic rock', 'comic', 'punk', 'skate punk'],
#  [],
#  ['chicago hardcore', 'chicago punk', 'hardcore punk', 'pop punk', 'punk'],
#  ['bow pop', 'celtic punk', 'celtic rock', 'comic', 'punk', 'skate punk'],
#  ['alternative metal',
#   'canadian pop punk',
#   'canadian punk',
#   'nu metal',
#   'pop punk',
#   'punk'],
#  ['album rock',
#   'classic rock',
#   'country rock',
#   'folk rock',
#   'heartland rock',
#   'mellow gold',
#   'pop rock',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['album rock',
#   'classic rock',
#   'country rock',
#   'folk rock',
#   'hard rock',
#   'heartland rock',
#   'mellow gold',
#   'pop rock',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock'],
#  ['alternative hip hop',
#   'conscious hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'jazz rap',
#   'queens hip hop',
#   'rap'],
#  ['cali rap',
#   'gangster rap',
#   'hyphy',
#   'oakland hip hop',
#   'west coast rap',
#   'west coast trap'],
#  ['anarcho-punk'],
#  ['bow pop', 'celtic punk', 'celtic rock', 'comic', 'punk', 'skate punk'],
#  ['alternative rock', 'garage rock', 'modern rock', 'permanent wave', 'rock'],
#  ['south african alternative', 'south african pop', 'south african rock'],
#  ['australian indie folk',
#   'folk-pop',
#   'indie anthem-folk',
#   'indie folk',
#   'stomp and holler'],
#  ['alternative r&b', 'indie r&b', 'memphis hip hop', 'underground hip hop']]

# %%
print(song_dataset.shape)
print(len(genres))
# Out:
# (351, 18)
# 351

# %%
song_dataset['genres'] = genres

# %%
#filters out songs from dataset does not match genre of playlist
def getRelevantData(df1, df2):
    
    df1_genre_list = []
    for i in range(0, len(df1)):
        for j in range(0, len(df1['genres'][i])):
            specific_genre = df1['genres'][i][j]
            if (specific_genre in df1_genre_list):
                pass
            else:
                df1_genre_list.append(specific_genre)
                
    irrelevant_songs_ids = []
    for k in range(0, len(df2)):
        song_genres = []
        for m in range(0, len(df2['genres'][k])):
            specific_genre = df2['genres'][k][m]
            song_genres.append(specific_genre)
        
        appears = False
        for n in range(0, len(song_genres)):
            if(song_genres[n] in df1_genre_list):
                appears = True
            
        if appears == False:
            irrelevant_songs_ids.append(k)

    relevant_df2 = df2.drop(irrelevant_songs_ids)
    
    return relevant_df2

# %%
getRelevantData(user_playlist, song_dataset)
# Out:
#                                                   name  \
# 0                  What Is Love 2016 - Mike Mago Remix
# 1             Love Me Now - Dave Audé Remix Radio Edit
# 3    I Will Be Here (feat. Sneaky Sound System) - (...
# 5                      I'll Take You - Solidisco Remix
# 8                             Hold Me Up - AM2PM Remix
# ..                                                 ...
# 324                                        Dem My Dogs
# 326                                            Too Bad
# 343                                Solid Wall of Sound
# 344                                         Get Stupid
# 350                                           Reckless
#
#                                                album                artist  \
# 0                        What Is Love 2016 (Remixes)      Lost Frequencies
# 1                              Love Me Now (Remixes)           John Legend
# 3                               Kaleidoscope Remixed                Tiësto
# 5                            I'll Take You (Remixes)           MSTR ROGERS
# 8                           Hold Me Up (AM2PM Remix)         Conrad Sewell
# ..                                               ...                   ...
# 324                                          Subluxe                 Healy
# 326                                 Too Bad - Single               IshDARR
# 343  We got it from Here... Thank You 4 Your service  A Tribe Called Quest
# 344                                    Ronald Dregan               Mac Dre
# 350                                          Subluxe                 Healy
#
#     release_date  length  popularity  danceability  energy  key  loudness  \
# 0     2016-12-09  209882           2         0.665   0.751    1    -5.687
# 1     2016-12-01  219106          37         0.595   0.841    8    -4.240
# 3           2010  237066           0         0.722   0.723    6    -5.188
# 5     2016-01-22  196742          16         0.725   0.806    9    -3.482
# 8     2015-08-21  327029           0         0.785   0.598    4    -9.151
# ..           ...     ...         ...           ...     ...  ...       ...
# 324   2017-06-09  248480           0         0.871   0.387   10    -9.535
# 326   2015-08-17  193071          40         0.625   0.726    2    -5.617
# 343   2016-11-11  223346          45         0.670   0.684    9    -6.053
# 344   2004-07-20  242626          49         0.844   0.540   10    -6.100
# 350   2017-06-09  237157           0         0.846   0.366    2    -8.415
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0       0       0.0596       0.03840          0.000033    0.0573    0.445
# 1       1       0.0796       0.03220          0.000000    0.0847    0.761
# 3       0       0.0644       0.01620          0.000017    0.0709    0.522
# 5       1       0.0331       0.00285          0.011900    0.0241    0.669
# 8       0       0.0456       0.00698          0.044700    0.0533    0.859
# ..    ...          ...           ...               ...       ...      ...
# 324     1       0.5450       0.73000          0.000004    0.1110    0.368
# 326     1       0.1460       0.09330          0.000000    0.2340    0.337
# 343     0       0.4010       0.31100          0.000274    0.1810    0.473
# 344     0       0.3060       0.27900          0.000000    0.0823    0.654
# 350     1       0.4170       0.50900          0.000028    0.2360    0.421
#
#        tempo  time_signature  \
# 0    124.052               4
# 1    124.973               4
# 3    127.831               4
# 5    123.965               4
# 8    123.016               4
# ..       ...             ...
# 324   59.964               4
# 326  139.951               4
# 343  146.054               4
# 344   91.053               4
# 350   81.179               4
#
#                                                 genres
# 0    [belgian edm, edm, pop, pop dance, tropical ho...
# 1    [neo soul, pop, pop soul, r&b, urban contempor...
# 3    [big room, brostep, dance pop, dutch edm, edm,...
# 5                                      [neo soul, r&b]
# 8                [edm, pop, pop dance, tropical house]
# ..                                                 ...
# 324  [alternative r&b, indie r&b, memphis hip hop, ...
# 326  [deep underground hip hop, milwaukee hip hop, ...
# 343  [alternative hip hop, conscious hip hop, east ...
# 344  [cali rap, gangster rap, hyphy, oakland hip ho...
# 350  [alternative r&b, indie r&b, memphis hip hop, ...
#
# [149 rows x 19 columns]

# %%
#machine learning model
knn = NearestNeighbors(n_neighbors=10, metric='cosine')

# %%
ml_features_for_user_playlist = createFullPlaylistDf(user_ids)

# %%
ml_features_for_song_dataset = getRelevantData(user_playlist, song_dataset)

# %%
ml_features_for_user_playlist.drop(['name',  'album',  'artist', 'release_date', 'popularity', 'genres'], axis=1, inplace=True)

# %%
ml_features_for_user_playlist
# Out:
#      length  danceability  energy  key  loudness  mode  speechiness  \
# 0    131761         0.782   0.659    1    -3.103     1       0.2480
# 1    167704         0.803   0.689    1    -5.318     0       0.4030
# 2    101851         0.755   0.695    9    -5.963     1       0.2600
# 3    109373         0.829   0.582    7    -5.721     0       0.0415
# 4    141040         0.938   0.559   10    -6.734     1       0.3120
# ..      ...           ...     ...  ...       ...   ...          ...
# 111  222651         0.676   0.815    1    -3.427     1       0.2780
# 112  158667         0.773   0.614   11    -5.490     0       0.0776
# 113  190824         0.732   0.543   11   -10.747     1       0.2400
# 114  134011         0.767   0.508    9    -7.850     1       0.3480
# 115  154560         0.755   0.517    4    -9.804     0       0.0751
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.06960          0.000000    0.1680    0.336  148.030
# 1         0.21500          0.000000    0.2830    0.684  157.517
# 2         0.01790          0.000000    0.1070    0.493  128.063
# 3         0.52500          0.000000    0.0759    0.510  108.028
# 4         0.05460          0.000000    0.1570    0.760  119.901
# ..            ...               ...       ...      ...      ...
# 111       0.01520          0.000004    0.1070    0.591  162.054
# 112       0.06780          0.000000    0.0873    0.700  115.015
# 113       0.00849          0.000194    0.1080    0.523  155.924
# 114       0.13500          0.000000    0.1190    0.452  159.806
# 115       0.75400          0.000000    0.1270    0.699  129.027
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 111               4
# 112               4
# 113               4
# 114               4
# 115               4
#
# [116 rows x 13 columns]

# %%
ml_features_for_user_playlist.shape
# Out:
# (116, 13)

# %%
ml_features_for_song_dataset.drop(['name',  'album',  'artist', 'release_date', 'popularity', 'genres'], axis=1, inplace=True)

# %%
ml_features_for_song_dataset
# Out:
#      length  danceability  energy  key  loudness  mode  speechiness  \
# 0    209882         0.665   0.751    1    -5.687     0       0.0596
# 1    219106         0.595   0.841    8    -4.240     1       0.0796
# 3    237066         0.722   0.723    6    -5.188     0       0.0644
# 5    196742         0.725   0.806    9    -3.482     1       0.0331
# 8    327029         0.785   0.598    4    -9.151     0       0.0456
# ..      ...           ...     ...  ...       ...   ...          ...
# 324  248480         0.871   0.387   10    -9.535     1       0.5450
# 326  193071         0.625   0.726    2    -5.617     1       0.1460
# 343  223346         0.670   0.684    9    -6.053     0       0.4010
# 344  242626         0.844   0.540   10    -6.100     0       0.3060
# 350  237157         0.846   0.366    2    -8.415     1       0.4170
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.03840          0.000033    0.0573    0.445  124.052
# 1         0.03220          0.000000    0.0847    0.761  124.973
# 3         0.01620          0.000017    0.0709    0.522  127.831
# 5         0.00285          0.011900    0.0241    0.669  123.965
# 8         0.00698          0.044700    0.0533    0.859  123.016
# ..            ...               ...       ...      ...      ...
# 324       0.73000          0.000004    0.1110    0.368   59.964
# 326       0.09330          0.000000    0.2340    0.337  139.951
# 343       0.31100          0.000274    0.1810    0.473  146.054
# 344       0.27900          0.000000    0.0823    0.654   91.053
# 350       0.50900          0.000028    0.2360    0.421   81.179
#
#      time_signature
# 0                 4
# 1                 4
# 3                 4
# 5                 4
# 8                 4
# ..              ...
# 324               4
# 326               4
# 343               4
# 344               4
# 350               4
#
# [149 rows x 13 columns]

# %%
def recommendationList(user_playlist, song_dataset):
    knn_model = knn.fit(song_dataset)
    
    recommendation_frequency = []
    for i in range(0, len(song_dataset)):
        recommendation_frequency.append(0)
        
    for j in range(0, len(user_playlist)):
        distances, indices = knn_model.kneighbors([user_playlist.iloc[j]])
        for k in range(0, len(indices[0])):
            recommendation_frequency[indices[0][k]] += 1

    return recommendation_frequency

# %%
#example of indices
knn_model = knn.fit(ml_features_for_song_dataset)
distances, indices = knn_model.kneighbors([ml_features_for_user_playlist.iloc[2]])
distances, indices
# Out:
# (array([[1.54029495e-08, 1.78547714e-08, 2.39049378e-08, 2.39512953e-08,
#          3.35899232e-08, 3.81700629e-08, 3.93364227e-08, 8.08306906e-08,
#          8.21051127e-08, 9.05314598e-08]]),
#  array([[ 19, 131,  39,  76,  18,  14, 128,  54,  38,  93]], dtype=int64))

# %%
test = recommendationList(ml_features_for_user_playlist, ml_features_for_song_dataset)

# %%
frequencies_of_recs = recommendationList(ml_features_for_user_playlist, ml_features_for_song_dataset)

def indicesOfMax(frequency_list):

    max_indices = []
    
    for i in range(0, 10):  
        frequency_max = frequency_list[0]
        frequency_max_index = 0

        for j in range(0, len(frequency_list)):
            if (frequency_list[j] > frequency_max):
                frequency_max = frequency_list[j]
                frequency_max_index = j
        
        print([frequency_max_index, frequency_max])
    
        max_indices.append(frequency_max_index)
        frequency_list.pop(frequency_max_index)    
    
    return max_indices

# %%
sorted_indices = indicesOfMax(test)
# Out:
# [93, 47]
# [54, 46]
# [38, 45]
# [125, 31]
# [138, 30]
# [14, 29]
# [41, 29]
# [48, 29]
# [100, 29]
# [100, 29]

# %%
song_dataset.iloc[sorted_indices]
# Out:
#                                                   name  \
# 93                                    Better Slow Down
# 54                                   Ends of the Earth
# 38                                               Be Ok
# 125                                       Marvins Room
# 138                          The Man Who Lives Forever
# 14                           I Love You Always Forever
# 41   Hope She Cheats On You (With A Basketball Player)
# 48                            Something Just Like This
# 100                                        Hungry Face
# 100                                        Hungry Face
#
#                             album             artist release_date  length  \
# 93                       Sketches  Conner Youngblood   2012-04-12  239294
# 54                Lonesome Dreams         Lord Huron   2013-01-21  284146
# 38                           I Am  Chrisette Michele   2007-01-01  222960
# 125            Take Care (Deluxe)              Drake   2011-11-15  347226
# 138               Lonesome Dreams         Lord Huron   2013-01-21  318813
# 14                     The Valley          Betty Who   2017-03-24  223160
# 41   Late Nights & Early Mornings   Marsha Ambrosius   2011-02-25  243653
# 48         Memories...Do Not Open   The Chainsmokers   2017-04-07  247160
# 100      Les Revenants Soundtrack             Mogwai   2013-02-25  144693
# 100      Les Revenants Soundtrack             Mogwai   2013-02-25  144693
#
#      popularity  danceability  energy  key  loudness  mode  speechiness  \
# 93            9         0.786   0.364    0   -12.075     1       0.0413
# 54            0         0.555   0.584    4    -8.667     1       0.0301
# 38           26         0.798   0.595    7    -6.390     1       0.1670
# 125          73         0.492   0.260    9   -17.341     0       0.0921
# 138           0         0.629   0.726    4    -8.721     1       0.0277
# 14           55         0.747   0.687    0    -6.102     1       0.0449
# 41           35         0.501   0.666    6    -7.312     0       0.4140
# 48           83         0.617   0.635   11    -6.769     0       0.0317
# 100           0         0.579   0.607    7   -10.548     1       0.0282
# 100           0         0.579   0.607    7   -10.548     1       0.0282
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# 93         0.3770          0.027200    0.1090    0.498  113.405
# 54         0.2740          0.022800    0.2540    0.410  120.968
# 38         0.6920          0.000000    0.1210    0.306   99.984
# 125        0.6460          0.001780    0.0705    0.312  111.519
# 138        0.4680          0.004770    0.1030    0.670  125.004
# 14         0.3360          0.000000    0.3020    0.558  106.045
# 41         0.0596          0.000000    0.1230    0.392  163.925
# 48         0.0498          0.000014    0.1640    0.446  103.019
# 100        0.7940          0.926000    0.0717    0.360  108.965
# 100        0.7940          0.926000    0.0717    0.360  108.965
#
#      time_signature                                             genres
# 93                5                          [shimmer pop, shiver pop]
# 54                4          [indie folk, indie pop, stomp and holler]
# 38                4  [hip pop, neo soul, quiet storm, r&b, urban co...
# 125               5  [canadian hip hop, canadian pop, hip hop, pop ...
# 138               4          [indie folk, indie pop, stomp and holler]
# 14                4  [alt z, electropop, indie cafe pop, indie elec...
# 41                4  [conscious hip hop, gangster rap, hip hop, pop...
# 48                4  [dance pop, edm, electropop, pop, pop dance, t...
# 100               4  [british post-rock, chamber psych, cosmic post...
# 100               4  [british post-rock, chamber psych, cosmic post...

# %%
#example of algorithm run on one song
song_dataset.iloc[indices[0]]
# Out:
#                           name  \
# 19               Tyrone - Live
# 131                       Flax
# 39              Alone Together
# 76                  The Stairs
# 18                       Honey
# 14   I Love You Always Forever
# 128              Stubborn Love
# 54           Ends of the Earth
# 38                       Be Ok
# 93            Better Slow Down
#
#                                                  album              artist  \
# 19                                                Live         Erykah Badu
# 131                                Acid and Everything            Gem Club
# 39                                       Days & Nights               Daley
# 76                                          Loma Vista  Family of the Year
# 18   New Amerykah Part One (4th World War) [UK-AU-N...         Erykah Badu
# 14                                          The Valley           Betty Who
# 128                                      The Lumineers       The Lumineers
# 54                                     Lonesome Dreams          Lord Huron
# 38                                                I Am   Chrisette Michele
# 93                                            Sketches   Conner Youngblood
#
#     release_date  length  popularity  danceability  energy  key  loudness  \
# 19    1997-01-01  221866          53         0.464   0.598    1   -10.051
# 131   2010-07-06  218254          14         0.237   0.191    7   -13.151
# 39    2014-01-01  239960          30         0.510   0.504    0    -8.357
# 76          2012  231493           0         0.480   0.837    3    -4.252
# 18    2008-03-03  320986          14         0.398   0.801    6    -7.858
# 14    2017-03-24  223160          55         0.747   0.687    0    -6.102
# 128   2012-01-01  277333           0         0.596   0.555    0   -11.689
# 54    2013-01-21  284146           0         0.555   0.584    4    -8.667
# 38    2007-01-01  222960          26         0.798   0.595    7    -6.390
# 93    2012-04-12  239294           9         0.786   0.364    0   -12.075
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 19      0       0.1120        0.0241          0.000026     0.977    0.353
# 131     1       0.0416        0.9720          0.037300     0.125    0.120
# 39      0       0.1180        0.1570          0.000000     0.123    0.286
# 76      1       0.0330        0.0455          0.004590     0.374    0.314
# 18      0       0.3400        0.0308          0.003720     0.221    0.491
# 14      1       0.0449        0.3360          0.000000     0.302    0.558
# 128     1       0.0374        0.6170          0.039500     0.275    0.235
# 54      1       0.0301        0.2740          0.022800     0.254    0.410
# 38      1       0.1670        0.6920          0.000000     0.121    0.306
# 93      1       0.0413        0.3770          0.027200     0.109    0.498
#
#        tempo  time_signature  \
# 19   130.373               3
# 131  169.171               4
# 39    89.192               4
# 76   124.866               4
# 18    87.942               4
# 14   106.045               4
# 128  115.019               4
# 54   120.968               4
# 38    99.984               4
# 93   113.405               5
#
#                                                 genres
# 19   [afrofuturism, hip hop, indie r&b, neo soul, r...
# 131                        [boston indie, chamber pop]
# 39                               [alternative hip hop]
# 76                                  [stomp and holler]
# 18   [afrofuturism, hip hop, indie r&b, neo soul, r...
# 14   [alt z, electropop, indie cafe pop, indie elec...
# 128  [folk-pop, modern rock, pop, pop rock, stomp a...
# 54           [indie folk, indie pop, stomp and holler]
# 38   [hip pop, neo soul, quiet storm, r&b, urban co...
# 93                           [shimmer pop, shiver pop]

# %%
long_set_of_songs = import_json_playlist_x(r'C:\Users\ecusa\OneDrive\Desktop\MPSD\999.json', 100)
# Out:
# Progress: [####################] 100.0%

# %%
long_set_of_songs
# Out:
#                                             name  \
# 0     Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                          Toxic
# 2                    Crazy In Love (feat. Jay-Z)
# 3                                 Rock Your Body
# 4                                   It Wasn't Me
# ...                                          ...
# 6094  Midnight Train to Georgia - Single Version
# 6095                                    My Thang
# 6096                               Pass The Peas
# 6097                    Laisse tomber les filles
# 6098                     Theme for the Lime Cafe
#
#                                              album                    artist  \
# 0                                     The Cookbook             Missy Elliott
# 1                                      In The Zone            Britney Spears
# 2     Dangerously In Love (Alben für die Ewigkeit)                   Beyoncé
# 3                                        Justified         Justin Timberlake
# 4              Hot Shot (International Version #2)                    Shaggy
# ...                                            ...                       ...
# 6094                Imagination (Expanded Edition)  Gladys Knight & The Pips
# 6095                                          Hell               James Brown
# 6096                    James Brown's Funky People           Various Artists
# 6097                                Paris in April               April March
# 6098                    April March and Los Cincos               April March
#
#      release_date  length  popularity  danceability  energy  key  loudness  \
# 0      2005-07-04  226863          67         0.904   0.813    4    -7.105
# 1      2003-11-13  198800          82         0.774   0.838    5    -3.914
# 2      2003-06-23  235933          23         0.664   0.758    2    -6.583
# 3      2002-11-04  267266          76         0.892   0.714    4    -6.055
# 4            2000  227600           0         0.853   0.606    0    -4.596
# ...           ...     ...         ...           ...     ...  ...       ...
# 6094         1973  237120          37         0.570   0.438   10    -9.928
# 6095   1974-01-01  259760           0         0.523   0.743    1   -10.760
# 6096   1986-01-01  192160           0         0.561   0.311    2   -14.981
# 6097         1996  127280           0         0.606   0.949    4    -4.324
# 6098   2012-02-14  184133           0         0.480   0.522    0    -8.892
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        0       0.1210       0.03110          0.006970    0.0471    0.810
# 1        0       0.1140       0.02490          0.025000    0.2420    0.924
# 2        0       0.2100       0.00238          0.000000    0.0598    0.701
# 3        0       0.1410       0.20100          0.000234    0.0521    0.817
# 4        1       0.0713       0.05610          0.000000    0.3130    0.654
# ...    ...          ...           ...               ...       ...      ...
# 6094     0       0.0404       0.18900          0.000006    0.1010    0.425
# 6095     1       0.2400       0.04370          0.000000    0.3220    0.648
# 6096     1       0.2650       0.26000          0.000237    0.3530    0.702
# 6097     1       0.0461       0.47300          0.000000    0.3840    0.906
# 6098     0       0.0272       0.45700          0.001550    0.1150    0.258
#
#         tempo  time_signature
# 0     125.461               4
# 1     143.040               4
# 2      99.259               4
# 3     100.972               4
# 4      94.759               4
# ...       ...             ...
# 6094   89.246               4
# 6095  202.607               4
# 6096  195.996               4
# 6097  139.121               4
# 6098  139.667               4
#
# [6099 rows x 18 columns]

# %%
def add_genres_w_try(total_tracks_df_ids_features):
    genres = []
    for i in range (0, len(total_tracks_df_ids_features)):   
        result = sp.search(total_tracks_df_ids_features['artist'][i]) 
        
        print(i)
        
        try:
            track = result['tracks']['items'][0]
            artist = sp.artist(track["artists"][0]["external_urls"]["spotify"])
            genres.append(artist['genres'])
        
        except IndexError:
            print("Index Error occurred")
            genres.append([])
        
        finally:
            update_progress(i/len(total_tracks_df_ids_features))
        
    return genres

# %%
long_genres = add_genres_w_try(long_set_of_songs)
long_genres
# Out:
# Progress: [####################] 100.0%
# [['dance pop', 'hip pop', 'pop', 'post-teen pop', 'r&b', 'urban contemporary'],
#  ['dance pop', 'pop', 'post-teen pop'],
#  ['houston rap', 'pop', 'pop rap', 'trap queen'],
#  ['dance pop', 'pop'],
#  ['dance pop', 'pop rap', 'reggae fusion'],
#  ['atl hip hop',
#   'dance pop',
#   'pop',
#   'r&b',
#   'south carolina hip hop',
#   'urban contemporary'],
#  ['atl hip hop',
#   'dance pop',
#   'pop',
#   'r&b',
#   'south carolina hip hop',
#   'urban contemporary'],
#  ['dance pop',
#   'girl group',
#   'pop',
#   'pop rap',
#   'post-teen pop',
#   'urban contemporary'],
#  ['dance pop',
#   'girl group',
#   'hip pop',
#   'neo soul',
#   'pop',
#   'r&b',
#   'urban contemporary'],
#  ['atl hip hop', 'dirty south rap', 'hip hop', 'rap', 'southern hip hop'],
#  ['canadian latin', 'canadian pop', 'dance pop', 'pop', 'pop rap'],
#  ['dance pop',
#   'neo mellow',
#   'pop',
#   'pop rock',
#   'post-teen pop',
#   'urban contemporary',
#   'viral pop'],
#  ['dance pop',
#   'neo mellow',
#   'pop',
#   'pop rock',
#   'post-teen pop',
#   'urban contemporary',
#   'viral pop'],
#  ['dance pop',
#   'neo mellow',
#   'pop',
#   'pop rock',
#   'post-teen pop',
#   'urban contemporary',
#   'viral pop'],
#  ['dance pop',
#   'hip pop',
#   'pop rap',
#   'post-teen pop',
#   'r&b',
#   'urban contemporary'],
#  ['dance pop',
#   'hip hop',
#   'hip pop',
#   'pop r&b',
#   'r&b',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'urban contemporary'],
#  ['canadian pop', 'candy pop', 'dance pop', 'pop', 'post-teen pop'],
#  ['dance pop', 'pop', 'pop rap', 'r&b', 'rap'],
#  ['houston rap', 'pop', 'pop rap', 'trap queen'],
#  ['dance pop',
#   'girl group',
#   'hip pop',
#   'neo soul',
#   'pop',
#   'r&b',
#   'urban contemporary'],
#  ['alternative metal', 'nu metal'],
#  ['dance pop', 'pop', 'pop rap'],
#  ['comic', 'pop punk', 'texas pop punk'],
#  ['boy band',
#   'neo mellow',
#   'neon pop punk',
#   'pixie',
#   'pop punk',
#   'pop rock',
#   'post-teen pop'],
#  ['dance pop', 'pop', 'pop rap', 'r&b', 'rap'],
#  ['boy band', 'dance pop', 'pop', 'pop rock', 'post-teen pop'],
#  ['sad rap'],
#  ['bubblegum dance',
#   'dance pop',
#   'eurodance',
#   'europop',
#   'german techno',
#   'melbourne bounce international',
#   'pop rap'],
#  ['nz pop'],
#  ['dance pop', 'latin', 'miami hip hop', 'pop', 'pop rap'],
#  ['australian hip hop'],
#  ['neo mellow', 'neon pop punk', 'pop punk', 'pop rock', 'post-teen pop'],
#  ['dance pop', 'pop rap', 'post-teen pop'],
#  ['dance pop', 'pop', 'pop rap', 'r&b', 'rap'],
#  ['dance pop', 'electropop', 'pop', 'pop rock', 'post-teen pop'],
#  ['dance pop', 'latin', 'miami hip hop', 'pop', 'pop rap'],
#  ['canadian pop', 'pop', 'post-teen pop'],
#  ['dance pop', 'escape room', 'indietronica', 'new rave'],
#  ['dance rock', 'modern rock', 'permanent wave', 'rock'],
#  ['pop punk', 'punk', 'socal pop punk'],
#  ['dance pop',
#   'girl group',
#   'pop',
#   'pop rap',
#   'post-teen pop',
#   'urban contemporary'],
#  ['canadian pop', 'pop', 'post-teen pop'],
#  ['modern rock', 'neo mellow', 'pop punk', 'pop rock', 'post-teen pop'],
#  ['canadian pop', 'pop', 'post-teen pop'],
#  ['dance pop',
#   'lilith',
#   'neo mellow',
#   'piano rock',
#   'pop rock',
#   'post-teen pop'],
#  ['indie pop rap'],
#  ['australian hip hop'],
#  ['dance pop',
#   'neo mellow',
#   'pop',
#   'pop rock',
#   'post-teen pop',
#   'urban contemporary',
#   'viral pop'],
#  ['post-teen pop'],
#  ['canadian pop', 'candy pop', 'dance pop', 'pop', 'post-teen pop'],
#  ['neon pop punk', 'piano rock', 'pop punk', 'pop rock', 'post-teen pop'],
#  ['neo mellow', 'neon pop punk', 'pop punk', 'pop rock', 'post-teen pop'],
#  ['dance pop',
#   'girl group',
#   'hip pop',
#   'neo soul',
#   'pop',
#   'r&b',
#   'urban contemporary'],
#  ['japanese vgm', 'otacore', 'scorecore'],
#  ['japanese vgm', 'otacore', 'scorecore'],
#  ['japanese vgm', 'otacore', 'scorecore'],
#  ['japanese vgm', 'otacore', 'scorecore'],
#  ['japanese vgm', 'otacore', 'scorecore'],
#  ['japanese vgm', 'otacore', 'scorecore'],
#  ['otacore'],
#  ['british orchestra', 'orchestra', 'theme'],
#  ['hollywood', 'show tunes'],
#  ['hollywood', 'show tunes'],
#  ['hollywood', 'show tunes'],
#  ['hollywood', 'show tunes'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['alternative metal', 'alternative rock', 'pop rock', 'post-grunge', 'rock'],
#  ['finnish metal',
#   'finnish power metal',
#   'gothic metal',
#   'gothic symphonic metal',
#   'opera metal',
#   'power metal',
#   'symphonic metal'],
#  ['alternative metal', 'danish metal', 'danish rock'],
#  ['british invasion', 'classic rock', 'rock'],
#  ['british invasion', 'classic rock', 'rock'],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'country rock',
#   'hard rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'southern rock'],
#  ['acoustic pop', 'neo mellow', 'piano rock', 'pop rock'],
#  ['acoustic pop', 'neo mellow', 'piano rock', 'pop rock'],
#  ['album rock',
#   'classic rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'yacht rock'],
#  ['alt z', 'electropop', 'indie pop', 'pop', 'post-teen pop'],
#  ['electropop', 'modern rock', 'pop', 'pop rap'],
#  ['album rock',
#   'blues rock',
#   'classic rock',
#   'country rock',
#   'hard rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'southern rock'],
#  ['acoustic pop', 'neo mellow', 'piano rock', 'pop rock'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['british orchestra', 'orchestra', 'theme'],
#  ['glam metal', 'hard rock', 'rock'],
#  ['album rock',
#   'classic rock',
#   'country rock',
#   'rock',
#   'roots rock',
#   'southern rock',
#   'swamp rock'],
#  ['album rock',
#   'german hard rock',
#   'german metal',
#   'german rock',
#   'hard rock',
#   'metal',
#   'rock'],
#  ['australian dance',
#   'australian electropop',
#   'australian indie',
#   'downtempo',
#   'edm'],
#  ['australian dance',
#   'australian electropop',
#   'australian indie',
#   'downtempo',
#   'edm'],
#  ['australian dance',
#   'australian electropop',
#   'australian indie',
#   'downtempo',
#   'edm'],
#  ['australian dance',
#   'australian electropop',
#   'australian indie',
#   'downtempo',
#   'edm'],
#  ['australian dance',
#   'australian electropop',
#   'australian indie',
#   'downtempo',
#   'edm'],
#  ['australian dance',
#   'australian electropop',
#   'australian indie',
#   'downtempo',
#   'edm'],
#  ['australian dance',
#   'australian electropop',
#   'australian indie',
#   'downtempo',
#   'edm'],
#  ['k-pop', 'k-rap', 'korean r&b'],
#  ['dance pop', 'edm', 'electronic trap', 'pop', 'pop dance', 'pop rap'],
#  ['k-pop', 'korean pop'],
#  ['k-pop', 'korean pop'],
#  ['k-pop', 'k-pop boy group'],
#  ['electropop', 'pop'],
#  ['k-pop', 'korean pop'],
#  ['k-pop', 'korean pop'],
#  ['k-pop', 'korean pop'],
#  ['japanese chillhop'],
#  ['k-pop', 'k-rap', 'korean pop', 'korean r&b'],
#  ['k-pop', 'k-rap', 'korean pop', 'korean r&b'],
#  ['canadian old school hip hop', 'pop rap', 'toronto rap'],
#  ['canadian old school hip hop', 'pop rap', 'toronto rap'],
#  ['k-pop', 'k-rap', 'korean pop', 'korean r&b'],
#  [],
#  ['art pop',
#   'candy pop',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'hyperpop',
#   'metropopolis',
#   'pop',
#   'post-teen pop',
#   'uk pop'],
#  ['art pop',
#   'candy pop',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'hyperpop',
#   'metropopolis',
#   'pop',
#   'post-teen pop',
#   'uk pop'],
#  ['art pop',
#   'candy pop',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'hyperpop',
#   'metropopolis',
#   'pop',
#   'post-teen pop',
#   'uk pop'],
#  ['k-pop', 'k-rap', 'korean r&b'],
#  ['k-pop', 'korean pop'],
#  ['k-pop', 'korean pop'],
#  ['art pop',
#   'candy pop',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'hyperpop',
#   'metropopolis',
#   'pop',
#   'post-teen pop',
#   'uk pop'],
#  ['k-pop', 'k-pop boy group'],
#  ['k-pop', 'k-pop girl group'],
#  ['k-pop', 'korean pop', 'korean singer-songwriter'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['k-pop', 'k-pop boy group'],
#  ['k-pop', 'k-pop boy group'],
#  ['art pop',
#   'candy pop',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'hyperpop',
#   'metropopolis',
#   'pop',
#   'post-teen pop',
#   'uk pop'],
#  ['k-pop', 'k-pop girl group'],
#  ['k-pop', 'k-pop girl group'],
#  ['electro swing', 'nu jazz'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['electro swing', 'nu jazz'],
#  [],
#  ['k-pop', 'k-pop boy group'],
#  ['k-pop', 'k-pop boy group'],
#  ['k-pop', 'k-rap', 'korean r&b'],
#  ['k-pop', 'k-pop girl group'],
#  ['k-pop'],
#  ['k-pop'],
#  ['korean r&b'],
#  ['korean r&b'],
#  ['k-pop', 'korean pop'],
#  ['k-pop', 'k-pop girl group'],
#  ['k-pop', 'k-pop boy group'],
#  [],
#  ['canadian old school hip hop', 'pop rap', 'toronto rap'],
#  ['k-pop'],
#  ['k-pop', 'korean pop'],
#  [],
#  ['k-pop', 'korean pop'],
#  ['art pop',
#   'candy pop',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'hyperpop',
#   'metropopolis',
#   'pop',
#   'post-teen pop',
#   'uk pop'],
#  ['k-pop', 'k-pop boy group'],
#  [],
#  [],
#  ['k-pop'],
#  ['deep dubstep', 'dub reggae'],
#  ['k-pop', 'k-pop boy group'],
#  ['k-pop', 'k-pop boy group'],
#  ['k-pop', 'k-pop boy group'],
#  ['k-pop', 'k-pop boy group'],
#  ['classical', 'french romanticism', 'late romantic era'],
#  ['classical', 'french romanticism', 'late romantic era'],
#  ['indie garage rock', 'indie pop', 'indie surf'],
#  ['indie garage rock', 'indie pop', 'indie surf'],
#  ['bedroom pop', 'indie garage rock'],
#  ['bedroom pop', 'indie garage rock'],
#  ['queercore'],
#  ['new romantic',
#   'new wave',
#   'new wave pop',
#   'permanent wave',
#   'rock',
#   'soft rock',
#   'sophisti-pop',
#   'synthpop'],
#  ['hamburg hip hop'],
#  ['indie garage rock'],
#  ['indie garage rock'],
#  ['indie garage rock'],
#  ['adult standards', 'funk', 'indie r&b', 'motown', 'quiet storm', 'soul'],
#  ['adult standards', 'funk', 'indie r&b', 'motown', 'quiet storm', 'soul'],
#  ['adult standards', 'funk', 'indie r&b', 'motown', 'quiet storm', 'soul'],
#  ['adult standards', 'funk', 'indie r&b', 'motown', 'quiet storm', 'soul'],
#  ['uk alternative pop'],
#  ['australian indie', 'australian indie rock', 'australian pop'],
#  ['pop', 'post-teen pop'],
#  ['japanese chillhop', 'lo-fi beats'],
#  ['antiviral pop', 'comic'],
#  ['modern power pop'],
#  ['piano rock', 'washington indie'],
#  ['modern power pop'],
#  ['alternative dance',
#   'alternative rock',
#   'dance-punk',
#   'indie rock',
#   'indietronica',
#   'modern rock',
#   'new rave',
#   'rock'],
#  ['chicago indie',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'stomp and holler'],
#  ['alternative dance',
#   'art pop',
#   'baroque pop',
#   'brooklyn indie',
#   'chillwave',
#   'dream pop',
#   'freak folk',
#   'indie pop',
#   'indie rock',
#   'modern rock',
#   'new rave',
#   'new weird america',
#   'nu gaze',
#   'shimmer pop',
#   'stomp and holler'],
#  ['alternative dance',
#   'art pop',
#   'baroque pop',
#   'brooklyn indie',
#   'chillwave',
#   'dream pop',
#   'freak folk',
#   'indie pop',
#   'indie rock',
#   'modern rock',
#   'new rave',
#   'new weird america',
#   'nu gaze',
#   'shimmer pop',
#   'stomp and holler'],
#  ['baroque pop', 'indie rock', 'modern rock'],
#  ['freak folk', 'garage pop', 'indie garage rock'],
#  ['nashville indie'],
#  ['alternative pop rock', 'modern alternative rock', 'modern rock', 'rock'],
#  ['alternative dance',
#   'australian indie',
#   'indie pop',
#   'indietronica',
#   'new rave'],
#  ['alternative country',
#   'alternative rock',
#   'indie folk',
#   'indie rock',
#   'jam band',
#   'louisville indie',
#   'melancholia',
#   'modern rock',
#   'new americana',
#   'rock',
#   'roots rock',
#   'stomp and holler'],
#  ['conscious hip hop', 'hip hop', 'north carolina hip hop', 'rap'],
#  ['conscious hip hop', 'hip hop', 'north carolina hip hop', 'rap'],
#  ['afrofuturism', 'alternative r&b', 'rap'],
#  ['boy band', 'hip hop', 'rap', 'underground hip hop'],
#  ['boy band', 'hip hop', 'rap', 'underground hip hop'],
#  ['conscious hip hop', 'hip hop', 'rap', 'west coast rap'],
#  ['escape room', 'hyperpop'],
#  ['escape room', 'hyperpop'],
#  ['canadian hip hop',
#   'canadian trap',
#   'dark trap',
#   'emo rap',
#   'ottawa rap',
#   'underground hip hop'],
#  ['experimental pop', 'glitchcore'],
#  ['experimental pop', 'glitchcore'],
#  ['experimental pop', 'glitchcore'],
#  ['ambient pop', 'dream pop', 'el paso indie', 'shoegaze'],
#  ['ambient pop', 'dream pop', 'el paso indie', 'shoegaze'],
#  ['indie pop', 'lo-fi beats', 'lo-fi emo', 'lo-fi indie'],
#  ['bubblegrunge', 'chicago indie', 'indie pop', 'pop'],
#  ['brighton indie', 'modern rock', 'rock'],
#  ['alternative rock',
#   'anti-folk',
#   'art pop',
#   'art rock',
#   'bay area indie',
#   'dream pop',
#   'escape room',
#   'experimental',
#   'experimental pop',
#   'experimental rock',
#   'freak folk',
#   'grave wave',
#   'indie rock',
#   'modern rock',
#   'new rave',
#   'noise pop'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['abstract hip hop',
#   'alternative hip hop',
#   'conscious hip hop',
#   'escape room',
#   'hip hop'],
#  ['abstract hip hop',
#   'alternative hip hop',
#   'conscious hip hop',
#   'escape room',
#   'hip hop'],
#  ['abstract hip hop',
#   'alternative hip hop',
#   'conscious hip hop',
#   'escape room',
#   'hip hop'],
#  ['abstract hip hop',
#   'alternative hip hop',
#   'conscious hip hop',
#   'escape room',
#   'hip hop'],
#  ['abstract hip hop',
#   'alternative hip hop',
#   'conscious hip hop',
#   'escape room',
#   'hip hop'],
#  ['alternative rock',
#   'modern power pop',
#   'modern rock',
#   'permanent wave',
#   'pop rock',
#   'rock'],
#  ['lo-fi beats'],
#  ['lo-fi beats'],
#  ['lo-fi beats'],
#  ['alternative dance',
#   'art pop',
#   'brooklyn indie',
#   'chillwave',
#   'electropop',
#   'escape room',
#   'indie pop',
#   'metropopolis',
#   'neo-synthpop',
#   'new rave',
#   'shimmer pop'],
#  ['experimental pop', 'kiwi rock', 'neo-psychedelic'],
#  ['alternative rock', 'grunge', 'pop rock', 'post-grunge'],
#  ['adult standards',
#   'contemporary vocal jazz',
#   'jazz pop',
#   'neo soul',
#   'soul',
#   'vocal jazz'],
#  ['dance pop', 'pop', 'urban contemporary'],
#  ['dance pop', 'pop', 'urban contemporary'],
#  ['modern dream pop', 'russian shoegaze'],
#  ['alternative rock'],
#  ['pop', 'r&b'],
#  ['nz indie'],
#  ['bedroom pop'],
#  ['dance rock',
#   'new romantic',
#   'new wave',
#   'new wave pop',
#   'synthpop',
#   'zolo'],
#  ['dance rock',
#   'new romantic',
#   'new wave',
#   'new wave pop',
#   'synthpop',
#   'zolo'],
#  ['dance rock',
#   'new romantic',
#   'new wave',
#   'new wave pop',
#   'synthpop',
#   'zolo'],
#  ['dance rock',
#   'new romantic',
#   'new wave',
#   'new wave pop',
#   'synthpop',
#   'zolo'],
#  ['dance rock',
#   'new romantic',
#   'new wave',
#   'new wave pop',
#   'synthpop',
#   'zolo'],
#  ['indie pop', 'lo-fi emo', 'lo-fi indie', 'slowcore', 'small room'],
#  ['modern dream pop'],
#  ['baroque pop',
#   'chamber pop',
#   'freak folk',
#   'indie folk',
#   'singer-songwriter'],
#  ['alternative dance',
#   'chillwave',
#   'dream pop',
#   'electropop',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'metropopolis',
#   'modern rock',
#   'shimmer pop',
#   'vapor soul'],
#  ['alternative dance',
#   'chillwave',
#   'dream pop',
#   'electropop',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'metropopolis',
#   'modern rock',
#   'shimmer pop',
#   'vapor soul'],
#  ['yacht rock'],
#  ['alternative pop',
#   'alternative rock',
#   'hardcore punk',
#   'new wave',
#   'post-hardcore',
#   'post-punk',
#   'power pop',
#   'punk'],
#  ['alternative pop',
#   'alternative rock',
#   'hardcore punk',
#   'new wave',
#   'post-hardcore',
#   'post-punk',
#   'power pop',
#   'punk'],
#  ['alternative pop',
#   'alternative rock',
#   'hardcore punk',
#   'new wave',
#   'post-hardcore',
#   'post-punk',
#   'power pop',
#   'punk'],
#  ['alternative pop',
#   'alternative rock',
#   'hardcore punk',
#   'new wave',
#   'post-hardcore',
#   'post-punk',
#   'power pop',
#   'punk'],
#  ['alternative pop',
#   'alternative rock',
#   'hardcore punk',
#   'new wave',
#   'post-hardcore',
#   'post-punk',
#   'power pop',
#   'punk'],
#  ['alternative r&b', 'dance pop', 'pop', 'r&b', 'urban contemporary'],
#  [],
#  ['electropop', 'indie pop', 'indie poptimism', 'indie soul', 'vapor soul'],
#  ['electropop', 'indie pop', 'indie poptimism', 'indie soul', 'vapor soul'],
#  ['contemporary country', 'country', 'country road'],
#  ['dmv rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'trap',
#   'underground hip hop',
#   'vapor trap'],
#  ['krautrock'],
#  ['hard rock', 'metal', 'old school thrash', 'rock', 'thrash metal'],
#  ['conscious hip hop', 'uk alternative hip hop', 'uk hip hop'],
#  ['retro soul'],
#  ['alternative hip hop',
#   'conscious hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'new jersey rap',
#   'rap',
#   'turntablism'],
#  [],
#  [],
#  ['garage rock', 'modern rock', 'permanent wave', 'rock', 'sheffield indie'],
#  [],
#  [],
#  ['indie pop', 'modern alternative rock', 'modern rock', 'rock'],
#  ['indie pop', 'modern alternative rock', 'modern rock', 'rock'],
#  ['alternative r&b', 'indie r&b', 'indie soul'],
#  ['british soul', 'funk', 'neo soul', 'psychedelic soul', 'soul'],
#  ['adult standards',
#   'jazz blues',
#   'soul',
#   'soul blues',
#   'torch song',
#   'vocal jazz'],
#  ['ohio hip hop', 'pop rap'],
#  ['chicago hardcore', 'chicago punk', 'post-hardcore', 'punk'],
#  ['chicago hardcore', 'chicago punk', 'post-hardcore', 'punk'],
#  ['chicago hardcore', 'chicago punk', 'post-hardcore', 'punk'],
#  ['indie garage rock', 'lo-fi indie', 'newfoundland indie', 'small room'],
#  ['bedroom pop', 'indie garage rock', 'indie pop', 'rochester mn indie'],
#  ['alternative r&b',
#   'art pop',
#   'chillwave',
#   'electropop',
#   'escape room',
#   'indie soul',
#   'metropopolis'],
#  ['pinoy indie', 'pinoy rock'],
#  ['ambient folk'],
#  ['indie garage rock'],
#  ['post-punk'],
#  ['indie garage rock', 'neo-psychedelic'],
#  ['alternative metal',
#   'alternative rock',
#   'grunge',
#   'permanent wave',
#   'pop rock',
#   'rock'],
#  ['beatlesque', 'britpop', 'madchester', 'permanent wave', 'rock'],
#  ['album rock', 'classic rock', 'hard rock', 'rock'],
#  ['folk',
#   'lilith',
#   'mellow gold',
#   'new wave pop',
#   'pop rock',
#   'singer-songwriter'],
#  ['atl hip hop',
#   'dance pop',
#   'girl group',
#   'hip hop',
#   'hip pop',
#   'new jack swing',
#   'pop',
#   'pop rap',
#   'r&b',
#   'urban contemporary'],
#  ['alternative metal',
#   'alternative rock',
#   'grunge',
#   'permanent wave',
#   'pop rock',
#   'rock'],
#  ['dance pop', 'europop', 'lilith', 'new wave pop', 'pop rock'],
#  ['lilith', 'pop rock'],
#  ['florida rap', 'underground hip hop', 'vapor trap'],
#  ['canadian pop',
#   'canadian singer-songwriter',
#   'ectofolk',
#   'folk',
#   'lilith',
#   'neo mellow',
#   'permanent wave',
#   'pop rock'],
#  ['alternative rock',
#   'britpop',
#   'permanent wave',
#   'pop rock',
#   'rock',
#   'shoegaze'],
#  ['alternative rock',
#   'grunge',
#   'permanent wave',
#   'pop rock',
#   'post-grunge',
#   'rock'],
#  ['pop rock', 'post-grunge'],
#  ['detroit hip hop', 'hip hop', 'rap'],
#  ['alt z',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'hip pop',
#   'pop',
#   'pop rap',
#   'post-teen pop',
#   'trap queen'],
#  ['folk',
#   'lilith',
#   'new wave pop',
#   'permanent wave',
#   'pop rock',
#   'singer-songwriter'],
#  ['mellow gold', 'neo mellow', 'pop rock'],
#  ['pop rap'],
#  ['australian hip hop'],
#  ['dance pop', 'edm', 'pop', 'pop rap'],
#  ['hip house', 'miami hip hop'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['dance pop', 'miami hip hop', 'pop', 'pop rap'],
#  ['dance pop', 'pop', 'pop rap'],
#  ['atl hip hop',
#   'dance pop',
#   'pop',
#   'r&b',
#   'south carolina hip hop',
#   'urban contemporary'],
#  ['pop', 'r&b', 'soul'],
#  ['gangster rap', 'hip hop', 'hip house', 'old school hip hop', 'rap'],
#  ['atl hip hop',
#   'dance pop',
#   'pop',
#   'r&b',
#   'south carolina hip hop',
#   'urban contemporary'],
#  ['dance pop', 'pop', 'post-teen pop'],
#  [],
#  ['adult standards',
#   'brill building pop',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'singer-songwriter',
#   'soft rock',
#   'yacht rock'],
#  ['dance pop', 'pop rap'],
#  ['dance pop', 'pop', 'post-teen pop'],
#  ['bubblegum dance',
#   'dance pop',
#   'eurodance',
#   'europop',
#   'german techno',
#   'melbourne bounce international',
#   'pop rap'],
#  ['canadian contemporary r&b', 'canadian pop', 'pop'],
#  ['dance pop', 'pop', 'post-teen pop'],
#  ['dance pop', 'miami hip hop', 'pop', 'pop rap'],
#  ['dance pop', 'latin', 'miami hip hop', 'pop', 'pop rap'],
#  ['dance pop', 'edm', 'pop', 'pop rap'],
#  ['detroit hip hop', 'hip hop', 'rap'],
#  ['pop', 'post-teen pop', 'talent show', 'uk pop'],
#  ['dance pop', 'pop', 'pop rap', 'r&b', 'rap'],
#  ['dance pop', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'queens hip hop'],
#  ['adult standards',
#   'jazz blues',
#   'soul',
#   'soul blues',
#   'torch song',
#   'vocal jazz'],
#  ['disco', 'funk rock'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'underground hip hop'],
#  ['pop', 'r&b', 'soul'],
#  ['dance pop', 'pop', 'pop rap'],
#  ['hip hop', 'pop rap'],
#  ['pop', 'r&b', 'soul'],
#  ['reggae', 'roots reggae'],
#  ['nz pop'],
#  ['pop', 'uk pop'],
#  ['dance pop', 'pop'],
#  ['acoustic pop', 'neo mellow', 'pop rock'],
#  ['acoustic pop', 'neo mellow', 'pop', 'pop rock', 'viral pop'],
#  ['neo mellow', 'pop rock'],
#  ['indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop',
#   'pop rock'],
#  ['hip pop', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary'],
#  ['british alternative rock'],
#  ['pop', 'post-teen pop'],
#  ['houston rap', 'pop', 'pop rap', 'trap queen'],
#  ['jam band', 'neo mellow', 'pop rock'],
#  ['dance pop', 'pop', 'pop rap'],
#  ['australian hip hop'],
#  ['contemporary country', 'country', 'country road', 'pop rock'],
#  ['contemporary country', 'country', 'country road', 'pop rock'],
#  ['contemporary country', 'country', 'country road', 'pop rock'],
#  ['contemporary country', 'country', 'country road', 'pop rock'],
#  ['contemporary country', 'country', 'country road', 'pop rock'],
#  ['contemporary country', 'country', 'country road', 'pop rock'],
#  ['album rock',
#   'classic rock',
#   'country rock',
#   'folk rock',
#   'hard rock',
#   'heartland rock',
#   'mellow gold',
#   'pop rock',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock'],
#  ['dance pop', 'edm', 'pop', 'pop rap'],
#  ['big room',
#   'brostep',
#   'dance pop',
#   'dutch edm',
#   'edm',
#   'house',
#   'pop',
#   'pop dance',
#   'slap house',
#   'trance',
#   'tropical house'],
#  ['dance pop', 'pop', 'pop rap'],
#  ['folk-pop', 'modern rock', 'pop', 'pop rock', 'stomp and holler'],
#  ['dance pop', 'miami hip hop', 'pop', 'pop rap'],
#  ['dance pop', 'miami hip hop', 'pop', 'pop rap'],
#  ['dance pop', 'miami hip hop', 'pop', 'pop rap'],
#  ['album rock', 'glam metal', 'glam punk', 'hard rock', 'sleaze rock'],
#  ['hip hop', 'new jack swing', 'rap'],
#  ['contemporary country', 'country pop'],
#  ['big room',
#   'brostep',
#   'dance pop',
#   'dutch edm',
#   'edm',
#   'house',
#   'pop',
#   'pop dance',
#   'slap house',
#   'trance',
#   'tropical house'],
#  ['dance pop', 'pop', 'pop rap', 'r&b', 'rap'],
#  ['edm', 'electro house', 'pop dance'],
#  ['indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop',
#   'pop rock'],
#  ['dance pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'st louis rap',
#   'urban contemporary'],
#  ['dance pop', 'pop', 'pop rap', 'r&b', 'rap'],
#  ['dance pop',
#   'edm',
#   'pop',
#   'pop dance',
#   'post-teen pop',
#   'tropical house',
#   'uk dance',
#   'uk funky'],
#  ['dance pop',
#   'pop',
#   'pop rap',
#   'pop rock',
#   'post-teen pop',
#   'social media pop'],
#  ['art pop',
#   'candy pop',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'hyperpop',
#   'metropopolis',
#   'pop',
#   'post-teen pop',
#   'uk pop'],
#  ['dance pop',
#   'edm',
#   'electro house',
#   'house',
#   'pop',
#   'pop dance',
#   'progressive house',
#   'uk dance'],
#  ['dance pop',
#   'latin',
#   'latin pop',
#   'latin viral pop',
#   'pop',
#   'rap latina',
#   'reggaeton',
#   'trap latino'],
#  ['canadian contemporary r&b', 'canadian pop', 'pop'],
#  ['dance pop', 'modern rock', 'pop', 'pop rap', 'seattle hip hop'],
#  ['dance pop', 'latin', 'miami hip hop', 'pop', 'pop rap'],
#  [],
#  ['album rock',
#   'classic rock',
#   'country rock',
#   'rock',
#   'roots rock',
#   'southern rock',
#   'swamp rock'],
#  ['alternative dance',
#   'chillwave',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'modern rock',
#   'shimmer pop'],
#  ['alternative metal',
#   'alternative rock',
#   'funk metal',
#   'funk rock',
#   'nu metal',
#   'pop rock',
#   'rap rock',
#   'reggae fusion',
#   'rock'],
#  ['funk',
#   'indie folk',
#   'modern blues rock',
#   'new americana',
#   'rock',
#   'stomp and holler'],
#  ['alternative metal', 'alternative rock', 'grunge', 'post-grunge'],
#  ['alternative metal',
#   'alternative rock',
#   'blues rock',
#   'modern rock',
#   'nu metal',
#   'palm desert scene',
#   'rock',
#   'stoner metal',
#   'stoner rock'],
#  ['irish rock', 'pop rock'],
#  ['indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'rock'],
#  ['indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'rock'],
#  ['indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'rock'],
#  ['shimmer pop'],
#  ['post-grunge'],
#  ['australian psych', 'neo-psychedelic'],
#  ['australian dance', 'australian pop', 'pop'],
#  ['australian dance', 'australian pop', 'pop'],
#  ['garage rock', 'modern rock', 'permanent wave', 'rock', 'sheffield indie'],
#  ['ninja'],
#  ['indie folk', 'irish singer-songwriter', 'neo mellow'],
#  ['french indie pop', 'french indietronica'],
#  ['alternative r&b',
#   'canadian contemporary r&b',
#   'chill r&b',
#   'indie r&b',
#   'pop',
#   'pop r&b',
#   'r&b',
#   'trap soul',
#   'urban contemporary'],
#  ['aussietronica', 'pop dance', 'tropical house'],
#  ['pop', 'post-teen pop'],
#  ['alt z', 'dance pop', 'electropop', 'indie poptimism', 'pop'],
#  ['australian reggae fusion'],
#  ['etherpop', 'indie electropop', 'indie poptimism', 'vapor soul'],
#  ['alt z', 'dance pop', 'electropop', 'indie poptimism', 'pop'],
#  ['melodic rap', 'philly rap', 'rap', 'trap'],
#  ['ccm',
#   'christian alternative rock',
#   'christian indie',
#   'christian music',
#   'folk-pop',
#   'indiecoustica',
#   'neo mellow',
#   'pop rock',
#   'worship'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['eau claire indie', 'indie folk', 'melancholia'],
#  ['east coast hip hop', 'hip hop', 'pop rap', 'rap'],
#  ['ohio hip hop', 'pop rap'],
#  ['nyc pop'],
#  ['downtempo bass', 'electra', 'vapor twitch'],
#  ['house', 'pop', 'uk dance'],
#  ['atl hip hop', 'hip hop', 'pop rap', 'rap'],
#  ['la pop', 'pop', 'post-teen pop'],
#  ['alternative r&b'],
#  [],
#  ['alternative dance', 'electronica', 'indie soul', 'new rave', 'nu disco'],
#  ['britpop', 'modern rock', 'pop rock', 'rock', 'welsh rock'],
#  ['east coast hip hop', 'hip hop', 'pop rap', 'rap'],
#  ['dance pop',
#   'edm',
#   'house',
#   'liquid funk',
#   'pop',
#   'pop dance',
#   'tropical house',
#   'uk dance',
#   'uk funky'],
#  ['british alternative rock'],
#  ['australian indie folk', 'indie folk', 'stomp and holler'],
#  ['chill r&b'],
#  ['bossa nova', 'mpb', 'nova mpb', 'samba', 'samba de roda', 'umbanda'],
#  ['world devotional'],
#  ['electropop', 'norwegian indie', 'norwegian pop', 'tropical house'],
#  ['bow pop',
#   'compositional ambient',
#   'icelandic classical',
#   'neo-classical',
#   'neoclassical darkwave'],
#  ['british soul', 'neo soul'],
#  ['downtempo', 'indie soul', 'indietronica', 'shimmer pop'],
#  ['indie anthem-folk', 'indie cafe pop', 'vapor soul'],
#  ['downtempo bass', 'electra', 'vapor twitch'],
#  ['vapor soul'],
#  ['chill r&b', 'pop'],
#  ['drum and bass', 'house', 'liquid funk', 'uk dance', 'uk dnb'],
#  ['tropical house'],
#  ['dance pop', 'electropop', 'pop', 'pop rap', 'post-teen pop'],
#  ['dance pop',
#   'edm',
#   'house',
#   'liquid funk',
#   'pop',
#   'pop dance',
#   'tropical house',
#   'uk dance',
#   'uk funky'],
#  ['pop'],
#  ['aussietronica',
#   'edm',
#   'electro house',
#   'electronic trap',
#   'electropop',
#   'escape room',
#   'future bass',
#   'vapor twitch'],
#  ['detroit hip hop', 'pop r&b', 'pop rap', 'r&b', 'rap', 'trap', 'trap queen'],
#  ['alternative dance',
#   'edm',
#   'indie poptimism',
#   'indietronica',
#   'new french touch',
#   'nu disco',
#   'tropical house'],
#  ['nyc pop'],
#  ['pop', 'post-teen pop'],
#  ['australian hip hop'],
#  ['dance pop',
#   'hip hop',
#   'pittsburgh rap',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['drum and bass', 'liquid funk'],
#  ['modern alternative rock', 'modern rock', 'rock', 'stomp pop', 'welsh rock'],
#  ['modern alternative rock', 'modern rock', 'rock', 'stomp pop', 'welsh rock'],
#  ['modern alternative rock', 'modern rock', 'punk blues', 'rock'],
#  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'funk metal',
#   'funk rock',
#   'nu metal',
#   'pop rock',
#   'rap rock',
#   'reggae fusion',
#   'rock'],
#  ['brighton indie', 'modern rock', 'rock'],
#  ['indie pop',
#   'indie rock',
#   'modern alternative rock',
#   'modern blues rock',
#   'modern rock',
#   'piano rock',
#   'pop rock',
#   'rock',
#   'stomp and holler'],
#  ['indie pop',
#   'indie rock',
#   'modern alternative rock',
#   'modern blues rock',
#   'modern rock',
#   'piano rock',
#   'pop rock',
#   'rock',
#   'stomp and holler'],
#  ['modern rock', 'rock'],
#  ['baroque pop', 'pop', 'uk alternative pop'],
#  ['baroque pop', 'pop', 'uk alternative pop'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['modern rock', 'rock'],
#  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock'],
#  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock'],
#  ['permanent wave', 'pop punk', 'punk'],
#  ['permanent wave', 'pop punk', 'punk'],
#  ['indie folk', 'indie pop', 'stomp and holler'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['indie rock', 'modern alternative rock', 'modern rock', 'rock'],
#  ['indie rock', 'modern rock'],
#  ['modern alternative rock', 'modern rock', 'rock', 'stomp pop', 'welsh rock'],
#  ['indie pop',
#   'indie rock',
#   'indietronica',
#   'la indie',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'rock',
#   'stomp and holler'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['alternative hip hop'],
#  ['baroque pop', 'indie rock', 'modern rock'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['album rock',
#   'art rock',
#   'beatlesque',
#   'bow pop',
#   'classic rock',
#   'folk rock',
#   'glam rock',
#   'mellow gold',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['reggae fusion', 'reggae rock'],
#  ['baroque pop', 'pop', 'uk alternative pop'],
#  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock'],
#  ['indie pop',
#   'indie rock',
#   'indietronica',
#   'la indie',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'rock',
#   'stomp and holler'],
#  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock'],
#  ['reggae fusion', 'uk reggae'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['indie pop', 'indie rock', 'modern rock', 'pop rock', 'washington indie'],
#  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['beatlesque',
#   'brill building pop',
#   'bubblegum pop',
#   'classic rock',
#   'country rock',
#   'folk rock',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'soft rock',
#   'sunshine pop'],
#  ['beatlesque',
#   'british invasion',
#   'classic rock',
#   'merseybeat',
#   'psychedelic rock',
#   'rock'],
#  ['dance pop', 'electropop', 'pop', 'pop rock', 'post-teen pop'],
#  ['modern alternative rock', 'modern rock', 'rock', 'stomp pop', 'welsh rock'],
#  ['alt z',
#   'electropop',
#   'indie cafe pop',
#   'indie pop',
#   'indiecoustica',
#   'pop',
#   'pop rock',
#   'stomp and holler'],
#  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock'],
#  ['modern alternative rock', 'modern rock', 'punk blues', 'rock'],
#  ['country', 'country rock', 'outlaw country', 'texas country'],
#  ['country', 'country rock', 'outlaw country', 'texas country'],
#  ['modern southern rock'],
#  ['contemporary country', 'country road', 'modern country rock'],
#  ['contemporary country',
#   'country',
#   'country road',
#   'country rock',
#   'outlaw country'],
#  ['contemporary country', 'country', 'country road'],
#  ['outlaw country', 'redneck'],
#  ['modern southern rock', 'texas country'],
#  ['outlaw country', 'red dirt', 'roots americana', 'texas country'],
#  ['contemporary country', 'country road', 'texas country'],
#  ['bakersfield sound',
#   'country',
#   'country rock',
#   'nashville sound',
#   'outlaw country'],
#  ['bakersfield sound',
#   'country',
#   'country rock',
#   'nashville sound',
#   'outlaw country'],
#  ['country', 'country rock', 'outlaw country'],
#  ['contemporary country', 'country', 'country road', 'country rock'],
#  ['country', 'country rock', 'outlaw country', 'texas country'],
#  ['bakersfield sound'],
#  ['country', 'country road', 'country rock'],
#  ['bakersfield sound'],
#  ['contemporary country', 'country', 'country road', 'country rock'],
#  ['contemporary country', 'country', 'country road', 'modern country rock'],
#  ['neo-traditional country', 'texas country'],
#  ['dfw rap', 'melodic rap', 'rap'],
#  ['canadian pop', 'pop', 'post-teen pop'],
#  ['chicago rap',
#   'dance pop',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'post-teen pop',
#   'r&b',
#   'southern hip hop',
#   'trap',
#   'urban contemporary'],
#  ['melodic rap', 'rap', 'trap'],
#  ['chicago rap',
#   'conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'political hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop'],
#  ['pop rap', 'rap', 'trap', 'viral trap'],
#  ['dance pop',
#   'gangster rap',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'r&b',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'urban contemporary'],
#  ['cali rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['detroit hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['kentucky hip hop', 'pop', 'pop rap', 'r&b', 'rap', 'trap'],
#  ['electropop', 'pop', 'pop rap'],
#  ['hip hop', 'philly rap', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['detroit hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['canadian latin', 'canadian pop', 'dance pop', 'pop', 'pop rap'],
#  ['gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'underground hip hop'],
#  ['ohio hip hop', 'pop rap'],
#  ['ohio hip hop', 'pop rap'],
#  ['conscious hip hop', 'hip hop', 'north carolina hip hop', 'rap'],
#  ['melodic rap', 'rap', 'trap'],
#  ['detroit hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['brooklyn drill'],
#  ['rap', 'slap house'],
#  ['pop rap'],
#  ['memphis hip hop', 'rap', 'southern hip hop', 'tennessee hip hop', 'trap'],
#  ['cali rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['conscious hip hop', 'hip hop', 'rap', 'west coast rap'],
#  ['hip hop', 'pop rap', 'portland hip hop', 'rap', 'underground hip hop'],
#  ['canadian pop', 'pop', 'post-teen pop'],
#  ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'rap'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['crunk',
#   'dirty south rap',
#   'gangster rap',
#   'hip hop',
#   'memphis hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['dance pop', 'modern rock', 'pop', 'pop rap', 'seattle hip hop'],
#  ['dfw rap', 'melodic rap', 'rap'],
#  ['memphis hip hop', 'rap', 'southern hip hop', 'tennessee hip hop', 'trap'],
#  ['hip hop',
#   'melodic rap',
#   'mississippi hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['melodic rap', 'rap', 'trap'],
#  ['rap rock'],
#  ['conscious hip hop', 'hip hop', 'north carolina hip hop', 'rap'],
#  ['electropop', 'indie pop rap', 'pop', 'pop rap'],
#  ['dance pop', 'modern rock', 'pop', 'pop rap', 'seattle hip hop'],
#  ['baton rouge rap', 'rap', 'southern hip hop', 'trap'],
#  ['hip hop',
#   'melodic rap',
#   'mississippi hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['baton rouge rap', 'rap', 'southern hip hop', 'trap'],
#  ['baton rouge rap', 'rap', 'southern hip hop', 'trap'],
#  ['baton rouge rap', 'rap', 'southern hip hop', 'trap'],
#  ['nyc rap', 'rap', 'trap'],
#  ['baton rouge rap', 'rap', 'southern hip hop', 'trap'],
#  ['florida rap',
#   'hip hop',
#   'melodic rap',
#   'miami hip hop',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['brooklyn drill'],
#  ['rap', 'slap house'],
#  ['ohio hip hop', 'pop rap'],
#  ['ohio hip hop', 'pop rap'],
#  ['comedy rap', 'pop rap', 'rap'],
#  ['detroit hip hop',
#   'detroit trap',
#   'hip hop',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['melodic rap', 'pop rap', 'r&b', 'rap', 'trap'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['comedy rap', 'pop rap', 'rap'],
#  ['melodic rap', 'rap', 'trap'],
#  ['gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['chicago rap',
#   'dance pop',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'post-teen pop',
#   'r&b',
#   'southern hip hop',
#   'trap',
#   'urban contemporary'],
#  ['melodic rap', 'rap', 'trap'],
#  ['hip hop', 'philly rap', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['florida rap',
#   'hip hop',
#   'melodic rap',
#   'miami hip hop',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['dance pop',
#   'gangster rap',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'r&b',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'urban contemporary'],
#  ['hip hop',
#   'melodic rap',
#   'mississippi hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['hip hop',
#   'melodic rap',
#   'mississippi hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap'],
#  ['dance pop', 'pop', 'pop rap'],
#  ['modern rock', 'pop rap'],
#  ['dance pop', 'pop', 'pop rap'],
#  ['modern rock', 'pop rap'],
#  ['dance pop', 'pop', 'pop rap'],
#  ['trap soul'],
#  ['alternative metal',
#   'alternative rock',
#   'blues rock',
#   'grunge',
#   'hard rock',
#   'modern rock',
#   'nu metal',
#   'rock'],
#  ['detroit hip hop', 'hip hop', 'rap'],
#  ['pop', 'r&b', 'soul'],
#  ['edm', 'glitch hop', 'jam band', 'jazztronica', 'livetronica'],
#  ['afrofuturism',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['filter house'],
#  ['alternative hip hop'],
#  ['chill lounge', 'german electronica'],
#  ['downtempo', 'electronica', 'nu jazz', 'trip hop'],
#  ['dance pop',
#   'gangster rap',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'r&b',
#   'rap',
#   'southern hip hop',
#   'trap',
#   'urban contemporary'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['alternative hip hop', 'hip hop', 'turntablism'],
#  ['art pop',
#   'dance pop',
#   'electropop',
#   'pop',
#   'swedish electropop',
#   'swedish indie pop',
#   'swedish pop'],
#  ['afrofuturism',
#   'alternative hip hop',
#   'electronica',
#   'escape room',
#   'experimental hip hop',
#   'glitch',
#   'glitch hop',
#   'hip hop',
#   'intelligent dance music',
#   'jazztronica',
#   'psychedelic hip hop',
#   'wonky'],
#  ['dance pop',
#   'electropop',
#   'metropopolis',
#   'pop',
#   'pop rap',
#   'post-teen pop',
#   'swedish electropop',
#   'swedish pop',
#   'swedish synthpop'],
#  ['dance pop', 'pop', 'r&b', 'urban contemporary'],
#  ['eau claire indie', 'indie folk', 'melancholia'],
#  ['nantes indie', 'turntablism'],
#  ['modern alternative rock',
#   'modern rock',
#   'pop',
#   'pop rock',
#   'rock',
#   'stomp pop'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['jazz quartet', 'nu jazz'],
#  ['canadian electronic',
#   'dark clubbing',
#   'edm',
#   'electra',
#   'electro house',
#   'electronic trap'],
#  ['jazz quartet', 'nu jazz'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['electro swing',
#   'electronica',
#   'hip-hop experimental',
#   'nu jazz',
#   'trip hop',
#   'turntablism'],
#  ['dance pop', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'queens hip hop'],
#  ['dance pop',
#   'edm',
#   'electropop',
#   'indietronica',
#   'metropopolis',
#   'pop',
#   'post-teen pop',
#   'tropical house',
#   'uk pop'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['alternative hip hop',
#   'big beat',
#   'electronica',
#   'jazztronica',
#   'nu jazz',
#   'turntablism'],
#  ['chillwave', 'electra', 'future bass', 'vapor twitch', 'wonky'],
#  ['edm', 'glitch hop', 'jam band', 'jazztronica', 'livetronica'],
#  ['edm', 'glitch hop', 'jam band', 'jazztronica', 'livetronica'],
#  ['alternative hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'jazz rap',
#   'rap',
#   'west coast rap'],
#  ['alternative dance', 'dance pop', 'electropop', 'neo-synthpop', 'new rave'],
#  ['alternative metal',
#   'alternative rock',
#   'funk metal',
#   'funk rock',
#   'modern rock',
#   'nu metal',
#   'pop rock',
#   'post-grunge',
#   'rock'],
#  ['afrofuturism',
#   'alternative hip hop',
#   'electronica',
#   'escape room',
#   'experimental hip hop',
#   'glitch',
#   'glitch hop',
#   'hip hop',
#   'intelligent dance music',
#   'jazztronica',
#   'psychedelic hip hop',
#   'wonky'],
#  ['neo soul', 'r&b', 'urban contemporary'],
#  ['emo rap', 'miami hip hop'],
#  ['big room',
#   'dutch trance',
#   'edm',
#   'electro house',
#   'pop dance',
#   'progressive house',
#   'trance'],
#  ['emo rap', 'miami hip hop'],
#  ['emo rap', 'miami hip hop'],
#  ['emo rap', 'miami hip hop'],
#  ['bass music',
#   'drill and bass',
#   'glitch hop',
#   'intelligent dance music',
#   'ninja',
#   'wonky'],
#  ['dance pop', 'edm', 'electronic trap', 'pop', 'pop dance', 'pop rap'],
#  ['downtempo', 'electronica', 'nu jazz', 'trip hop'],
#  ['chillwave', 'grave wave', 'witch house'],
#  ['canadian contemporary r&b', 'canadian pop', 'pop'],
#  ['grave wave', 'witch house'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['canadian hip hop',
#   'canadian pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'toronto rap'],
#  ['alternative dance',
#   'australian alternative rock',
#   'australian dance',
#   'collage pop',
#   'electronica',
#   'new rave',
#   'psychedelic hip hop'],
#  ['baroque pop', 'pop', 'uk alternative pop'],
#  ['dance pop',
#   'edm',
#   'electro house',
#   'moombahton',
#   'pop',
#   'pop dance',
#   'pop rap',
#   'tropical house'],
#  ['alternative hip hop'],
#  ['alternative dance',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'shimmer pop'],
#  ['downtempo', 'electronica', 'trip hop'],
#  ['alternative dance',
#   'aussietronica',
#   'australian dance',
#   'australian indie',
#   'indie soul',
#   'nu disco'],
#  ['indie electronica',
#   'italian electronica',
#   'latintronica',
#   'pop electronico',
#   'puglia indie'],
#  ['chillstep', 'edm', 'substep'],
#  ['glitch hop'],
#  ['indie electronica',
#   'italian electronica',
#   'latintronica',
#   'pop electronico',
#   'puglia indie'],
#  ['bow pop',
#   'compositional ambient',
#   'icelandic classical',
#   'neo-classical',
#   'neoclassical darkwave'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['alternative dance',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'shimmer pop'],
#  ['big beat', 'bmore', 'downtempo', 'electronica', 'nu jazz', 'trip hop'],
#  ['electronica', 'laboratorio', 'trip hop'],
#  ['emo rap', 'miami hip hop'],
#  ['atl hip hop',
#   'dance pop',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'southern hip hop'],
#  ['afrofuturism',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['alternative rock',
#   'britpop',
#   'permanent wave',
#   'pop rock',
#   'rock',
#   'shoegaze'],
#  ['afrofuturism',
#   'alternative hip hop',
#   'electronica',
#   'escape room',
#   'experimental hip hop',
#   'glitch',
#   'glitch hop',
#   'hip hop',
#   'intelligent dance music',
#   'jazztronica',
#   'psychedelic hip hop',
#   'wonky'],
#  ['emo rap', 'miami hip hop'],
#  ['chillstep', 'edm', 'substep'],
#  ['alternative hip hop',
#   'conscious hip hop',
#   'east coast hip hop',
#   'gangster rap',
#   'golden age hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'jazz rap',
#   'queens hip hop',
#   'rap'],
#  ['alternative hip hop'],
#  ['dream pop'],
#  ['alternative dance',
#   'chillwave',
#   'dream pop',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'neo-psychedelic',
#   'neo-synthpop',
#   'new rave',
#   'nu gaze',
#   'shimmer pop'],
#  ['glitch hop'],
#  [],
#  ['chillwave', 'shimmer pop'],
#  ['chillwave',
#   'electronica',
#   'indie soul',
#   'new french touch',
#   'shimmer pop',
#   'tropical house',
#   'vapor soul',
#   'vapor twitch'],
#  ['chillstep', 'edm', 'substep'],
#  ['chicago rap', 'rap'],
#  ['chillstep', 'edm', 'substep'],
#  ['art pop',
#   'baltimore indie',
#   'dream pop',
#   'indie pop',
#   'indie rock',
#   'modern dream pop'],
#  ['chillstep', 'edm', 'substep'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['alternative hip hop'],
#  ['alternative dance',
#   'electronica',
#   'folktronica',
#   'intelligent dance music',
#   'new rave'],
#  ['downtempo', 'electronica', 'nu jazz', 'trip hop'],
#  ['downtempo', 'electronica', 'livetronica', 'nu jazz', 'trip hop'],
#  [],
#  ['alternative dance',
#   'electronica',
#   'folktronica',
#   'intelligent dance music',
#   'new rave'],
#  ['detroit hip hop', 'hip hop', 'rap'],
#  ['electronica', 'electropop', 'future garage', 'new rave'],
#  ['afrofuturism',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  ['alternative hip hop',
#   'conscious hip hop',
#   'east coast hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'philly rap',
#   'political hip hop',
#   'southern hip hop'],
#  ['alternative dance',
#   'baroque pop',
#   'dance-punk',
#   'indie pop',
#   'indie rock',
#   'modern rock',
#   'new rave',
#   'swedish alternative rock',
#   'swedish indie pop'],
#  ['alternative dance',
#   'auckland indie',
#   'electropop',
#   'indie pop',
#   'indie poptimism',
#   'indie rock',
#   'indietronica',
#   'kiwi rock',
#   'metropopolis',
#   'modern rock',
#   'shimmer pop'],
#  ['alternative metal', 'nu metal'],
#  ['skweee'],
#  ['lo-fi beats'],
#  ['atl hip hop',
#   'dance pop',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'southern hip hop'],
#  ['downtempo', 'electronica', 'jazztronica', 'ninja', 'nu jazz', 'trip hop'],
#  ['art pop', 'chillwave'],
#  ['british soundtrack', 'compositional ambient', 'scorecore', 'soundtrack'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['latin alternative', 'latinx alternative'],
#  ['afrofuturism',
#   'alternative hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'psychedelic hip hop',
#   'turntablism'],
#  ['big beat',
#   'downtempo',
#   'electronica',
#   'hip hop',
#   'trip hop',
#   'turntablism'],
#  ['electronica', 'future garage', 'new rave'],
#  ['atl hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['alternative r&b',
#   'art pop',
#   'chillwave',
#   'electropop',
#   'escape room',
#   'indie soul',
#   'metropopolis'],
#  ['glitch hop'],
#  ['alternative r&b', 'indie jazz', 'indie r&b', 'indie soul', 'neo soul'],
#  ['downtempo bass', 'glitch hop'],
#  ['alternative dance',
#   'bitpop',
#   'dance-punk',
#   'digital hardcore',
#   'indietronica',
#   'neo-synthpop',
#   'new rave',
#   'nintendocore',
#   'nu gaze'],
#  ['chillstep', 'edm', 'substep'],
#  ['drum and bass', 'liquid funk'],
#  ['background music', 'focus'],
#  ['brostep',
#   'canadian electronic',
#   'chillstep',
#   'edm',
#   'electro house',
#   'electronic trap',
#   'electropop',
#   'filthstep',
#   'future bass',
#   'melodic dubstep',
#   'pop dance',
#   'pop edm'],
#  [],
#  ['alternative dance',
#   'chillwave',
#   'dream pop',
#   'electropop',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'metropopolis',
#   'modern rock',
#   'shimmer pop',
#   'vapor soul'],
#  ['canadian indie',
#   'canadian pop',
#   'chamber pop',
#   'indie pop',
#   'indie rock',
#   'stomp and holler'],
#  ['chillwave',
#   'dream pop',
#   'experimental pop',
#   'indie pop',
#   'indie rock',
#   'indie surf'],
# ...
#   'alternative rock',
#   'cyberpunk',
#   'electronic rock',
#   'industrial',
#   'industrial metal',
#   'industrial rock',
#   'nu metal',
#   'rock'],
#  ['alternative rock', 'grunge', 'permanent wave', 'rock'],
#  ['alternative rock', 'grunge', 'permanent wave', 'rock'],
#  ['alternative rock', 'grunge', 'permanent wave', 'rock'],
#  ['alternative rock', 'grunge', 'permanent wave', 'rock'],
#  ['alternative rock', 'grunge', 'permanent wave', 'rock'],
#  ['alternative rock', 'grunge', 'permanent wave', 'rock'],
#  ['alternative rock', 'dance pop', 'dance rock', 'permanent wave', 'pop rock'],
#  ['alternative rock', 'dance pop', 'dance rock', 'permanent wave', 'pop rock'],
#  ['alternative rock', 'dance pop', 'dance rock', 'permanent wave', 'pop rock'],
#  ['beatlesque', 'britpop', 'madchester', 'permanent wave', 'rock'],
#  ['beatlesque', 'britpop', 'madchester', 'permanent wave', 'rock'],
#  ['alternative metal',
#   'permanent wave',
#   'punk',
#   'rock',
#   'skate punk',
#   'socal pop punk'],
#  ['alternative rock', 'grunge', 'permanent wave', 'pop rock', 'rock'],
#  ['alternative rock', 'grunge', 'permanent wave', 'pop rock', 'rock'],
#  ['dance pop', 'pop', 'post-teen pop'],
#  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock'],
#  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock'],
#  ['alternative rock', 'pop rock'],
#  ['alternative metal',
#   'alternative rock',
#   'grunge',
#   'permanent wave',
#   'pop rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'grunge',
#   'permanent wave',
#   'pop rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'blues rock',
#   'grunge',
#   'hard rock',
#   'modern rock',
#   'nu metal',
#   'rock'],
#  ['alternative rock', 'pop rock', 'rock'],
#  ['reggae fusion', 'ska mexicano', 'ska punk'],
#  ['reggae fusion', 'ska mexicano', 'ska punk'],
#  ['alternative metal',
#   'alternative rock',
#   'funk metal',
#   'neo mellow',
#   'pop rock'],
#  ['alternative metal',
#   'alternative rock',
#   'funk metal',
#   'neo mellow',
#   'pop rock'],
#  ['alternative metal',
#   'alternative rock',
#   'funk metal',
#   'neo mellow',
#   'pop rock'],
#  ['alternative rock', 'neo mellow', 'pop rock', 'post-grunge', 'rock'],
#  ['alternative rock', 'neo mellow', 'pop rock', 'post-grunge', 'rock'],
#  ['alternative rock', 'neo mellow', 'pop rock', 'post-grunge', 'rock'],
#  ['alternative rock', 'pop rock', 'post-grunge'],
#  ['pop', 'post-teen pop', 'talent show', 'uk pop'],
#  ['neo mellow', 'pop rock', 'post-grunge'],
#  ['neo mellow', 'pop rock', 'post-grunge'],
#  ['alternative rock',
#   'britpop',
#   'permanent wave',
#   'pop rock',
#   'rock',
#   'shoegaze'],
#  ['alternative rock', 'mellow gold', 'neo mellow', 'pop rock', 'rock'],
#  ['alternative rock', 'neo mellow', 'pop rock', 'post-grunge'],
#  ['alternative rock', 'neo mellow', 'pop rock', 'post-grunge'],
#  ['alternative rock', 'neo mellow', 'pop rock', 'post-grunge'],
#  ['art pop',
#   'electropop',
#   'etherpop',
#   'indie folk',
#   'indie pop',
#   'indie poptimism',
#   'indie rock'],
#  ['art pop',
#   'electropop',
#   'etherpop',
#   'indie folk',
#   'indie pop',
#   'indie poptimism',
#   'indie rock'],
#  ['art pop',
#   'electropop',
#   'etherpop',
#   'indie folk',
#   'indie pop',
#   'indie poptimism',
#   'indie rock'],
#  ['indie folk',
#   'new americana',
#   'pop folk',
#   'stomp and flutter',
#   'stomp and holler'],
#  ['indie folk',
#   'new americana',
#   'pop folk',
#   'stomp and flutter',
#   'stomp and holler'],
#  ['uk alternative pop'],
#  ['uk alternative pop'],
#  ['indie pop',
#   'indie rock',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'rock',
#   'stomp and holler'],
#  ['alternative pop',
#   'alternative rock',
#   'anti-folk',
#   'indie punk',
#   'indie rock',
#   'lilith',
#   'olympia wa indie',
#   'riot grrrl'],
#  ['alternative country',
#   'alternative pop',
#   'alternative rock',
#   'chamber psych',
#   'dream pop',
#   'garage psych',
#   'indie rock',
#   'jangle pop',
#   'modern power pop',
#   'new wave',
#   'pop rock',
#   'power pop',
#   'scottish indie',
#   'shoegaze'],
#  ['albuquerque indie',
#   'alternative rock',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'modern rock',
#   'portland indie',
#   'stomp and holler'],
#  ['emo rap', 'miami hip hop'],
#  ['electropop',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop'],
#  ['alternative americana',
#   'art pop',
#   'dream pop',
#   'freak folk',
#   'indie folk',
#   'indie pop',
#   'indie rock'],
#  ['alternative americana',
#   'art pop',
#   'dream pop',
#   'freak folk',
#   'indie folk',
#   'indie pop',
#   'indie rock'],
#  ['gothenburg indie',
#   'indie folk',
#   'neo mellow',
#   'stomp and holler',
#   'swedish indie folk',
#   'swedish indie pop',
#   'swedish singer-songwriter'],
#  ['edm',
#   'electro house',
#   'electronic trap',
#   'electropop',
#   'future bass',
#   'pop dance',
#   'pop edm',
#   'vapor twitch'],
#  ['alternative rock',
#   'bubblegrunge',
#   'chillwave',
#   'cleveland indie',
#   'dance-punk',
#   'freak folk',
#   'garage psych',
#   'indie punk',
#   'indie rock',
#   'lo-fi',
#   'modern rock',
#   'noise pop',
#   'nu gaze',
#   'popgaze'],
#  ['modern rock', 'rock'],
#  ['alternative metal',
#   'canadian pop punk',
#   'canadian punk',
#   'nu metal',
#   'pop punk',
#   'punk'],
#  ['alternative metal',
#   'alternative rock',
#   'funk metal',
#   'funk rock',
#   'modern rock',
#   'nu metal',
#   'pop rock',
#   'post-grunge',
#   'rock'],
#  ['alternative dance',
#   'alternative rock',
#   'baroque pop',
#   'canadian indie',
#   'dance-punk',
#   'indie pop',
#   'indie rock',
#   'modern rock',
#   'new rave',
#   'permanent wave',
#   'quebec indie',
#   'rock'],
#  ['modern rock', 'rock'],
#  ['bow pop',
#   'compositional ambient',
#   'icelandic classical',
#   'neo-classical',
#   'neoclassical darkwave'],
#  ['neo mellow', 'pop', 'pop rock', 'singer-songwriter'],
#  ['modern rock', 'rock'],
#  ['alternative rock',
#   'blues rock',
#   'garage rock',
#   'modern alternative rock',
#   'modern blues rock',
#   'modern rock',
#   'punk blues',
#   'rock'],
#  ['acoustic pop',
#   'alternative country',
#   'folk',
#   'neo mellow',
#   'new americana',
#   'pop rock',
#   'roots rock',
#   'singer-songwriter',
#   'stomp and holler'],
#  ['indie poptimism', 'modern alternative rock', 'modern rock'],
#  ['indie poptimism', 'modern alternative rock', 'modern rock'],
#  ['alternative rock',
#   'anti-folk',
#   'dream pop',
#   'freak folk',
#   'idaho indie',
#   'indie pop',
#   'indie rock',
#   'lo-fi',
#   'modern rock',
#   'stomp and holler'],
#  ['melancholia', 'nu gaze', 'scottish indie', 'shoegaze'],
#  ['alternative country',
#   'country rock',
#   'folk',
#   'indie folk',
#   'new americana',
#   'roots rock',
#   'stomp and holler'],
#  ['alternative emo',
#   'asbury park indie',
#   'emo',
#   'modern rock',
#   'new jersey indie',
#   'pop punk'],
#  ['anime', 'j-pop'],
#  ['anime', 'j-pop'],
#  ['escape room', 'indie soul', 'lgbtq+ hip hop'],
#  ['emo', 'neo mellow', 'pop punk', 'pop rock'],
#  ['alternative rock', 'neo mellow', 'pop rock', 'post-grunge', 'rock'],
#  ['indie rock', 'power pop'],
#  ['indie pop',
#   'indie rock',
#   'modern alternative rock',
#   'modern blues rock',
#   'modern rock',
#   'piano rock',
#   'pop rock',
#   'rock',
#   'stomp and holler'],
#  ['alternative rock',
#   'art rock',
#   'dream pop',
#   'noise pop',
#   'nu gaze',
#   'rock',
#   'shoegaze'],
#  ['classic rock', 'permanent wave', 'punk', 'rock'],
#  ['indie pop',
#   'indie poptimism',
#   'indie rock',
#   'minneapolis indie',
#   'modern alternative rock',
#   'modern rock'],
#  ['indie pop',
#   'indie rock',
#   'la indie',
#   'metropopolis',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'stomp and holler'],
#  ['indie pop',
#   'indie rock',
#   'la indie',
#   'metropopolis',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'stomp and holler'],
#  ['german pop'],
#  ['afrofuturism', 'hip hop', 'indie soul'],
#  ['afrofuturism', 'hip hop', 'indie soul'],
#  ['hopebeat',
#   'indie poptimism',
#   'indie rockism',
#   'modern alternative rock',
#   'modern rock'],
#  ['classic rock', 'glam rock', 'rock'],
#  ['alternative dance',
#   'alternative rock',
#   'dance-punk',
#   'indie rock',
#   'modern rock',
#   'new rave',
#   'rock'],
#  ['indie anthem-folk', 'indie cafe pop', 'indie pop', 'new jersey indie'],
#  ['chillwave',
#   'indie rock',
#   'indie soul',
#   'kiwi rock',
#   'neo-psychedelic',
#   'new rave',
#   'portland hip hop',
#   'psychedelic pop'],
#  ['art pop',
#   'dance pop',
#   'electropop',
#   'metropopolis',
#   'nz pop',
#   'pop',
#   'post-teen pop'],
#  ['alt z', 'pop', 'post-teen pop', 'social media pop'],
#  ['alternative metal',
#   'alternative rock',
#   'blues rock',
#   'grunge',
#   'hard rock',
#   'modern rock',
#   'nu metal',
#   'rock'],
#  ['alternative dance',
#   'alternative rock',
#   'dance-punk',
#   'indie rock',
#   'modern rock',
#   'new rave',
#   'rock'],
#  ['art rock',
#   'dance rock',
#   'madchester',
#   'new romantic',
#   'new wave',
#   'new wave pop',
#   'permanent wave',
#   'post-punk',
#   'rock',
#   'synthpop',
#   'uk post-punk'],
#  ['art pop', 'pop'],
#  ['chamber pop',
#   'freak folk',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'seattle indie',
#   'stomp and holler'],
#  ['albuquerque indie',
#   'alternative rock',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'modern rock',
#   'portland indie',
#   'stomp and holler'],
#  ['british soul', 'neo soul'],
#  ['alt z', 'electropop', 'gauze pop', 'indie poptimism', 'pop'],
#  ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['uk alternative pop'],
#  ['emo', 'pop punk', 'punk', 'screamo', 'skate punk'],
#  ['canadian indie',
#   'canadian pop',
#   'chamber pop',
#   'indie pop',
#   'indie rock',
#   'stomp and holler'],
#  ['alternative dance',
#   'alternative rock',
#   'baroque pop',
#   'canadian indie',
#   'canadian rock',
#   'chillwave',
#   'dance-punk',
#   'freak folk',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'modern rock',
#   'nu gaze',
#   'stomp and holler'],
#  ['alternative r&b', 'hip hop', 'lgbtq+ hip hop', 'neo soul', 'pop'],
#  ['german pop'],
#  ['baroque pop',
#   'chamber pop',
#   'freak folk',
#   'indie folk',
#   'singer-songwriter'],
#  ['indie pop',
#   'indie rock',
#   'la indie',
#   'metropopolis',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'stomp and holler'],
#  ['indie pop',
#   'indie rock',
#   'la indie',
#   'metropopolis',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'stomp and holler'],
#  ['metropopolis'],
#  ['alternative rock',
#   'art rock',
#   'classic rock',
#   'glam rock',
#   'new wave',
#   'permanent wave',
#   'post-punk',
#   'protopunk',
#   'punk',
#   'rock'],
#  ['alt z',
#   'electropop',
#   'indie cafe pop',
#   'indie pop',
#   'indie poptimism',
#   'pop',
#   'post-teen pop',
#   'tropical house'],
#  ["children's music", 'musica para ninos'],
#  ['conscious hip hop',
#   'funk',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'hip house',
#   'rap',
#   'west coast rap'],
#  ['alternative rock',
#   'dc hardcore',
#   'indie rock',
#   'noise rock',
#   'post-hardcore',
#   'post-punk',
#   'punk',
#   'rock'],
#  ['alternative dance',
#   'chillwave',
#   'dream pop',
#   'electropop',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'metropopolis',
#   'modern rock',
#   'shimmer pop',
#   'vapor soul'],
#  ['indie anthem-folk', 'indie cafe pop', 'indie pop', 'new jersey indie'],
#  ['alternative rock',
#   'anti-folk',
#   'dream pop',
#   'freak folk',
#   'idaho indie',
#   'indie pop',
#   'indie rock',
#   'lo-fi',
#   'modern rock',
#   'stomp and holler'],
#  [],
#  ['chamber pop',
#   'freak folk',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'seattle indie',
#   'stomp and holler'],
#  ['classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'roots rock',
#   'singer-songwriter',
#   'soft rock'],
#  ['alternative metal',
#   'alternative rock',
#   'blues rock',
#   'grunge',
#   'hard rock',
#   'modern rock',
#   'nu metal',
#   'rock'],
#  ['britpop'],
#  ['dance pop', 'pop', 'urban contemporary'],
#  ['baroque pop', 'indie rock', 'modern rock'],
#  ['baroque pop', 'indie rock', 'modern rock'],
#  ['indie rock', 'modern rock'],
#  ['freak folk', 'gaian doom', 'sacramento indie'],
#  ['freak folk', 'gaian doom', 'sacramento indie'],
#  ['alternative emo',
#   'asbury park indie',
#   'emo',
#   'modern rock',
#   'new jersey indie',
#   'pop punk'],
#  ['art pop',
#   'bay area indie',
#   'chillwave',
#   'indie pop',
#   'indie rock',
#   'oakland indie',
#   'small room'],
#  ['alternative rock',
#   'art rock',
#   'melancholia',
#   'oxford indie',
#   'permanent wave',
#   'rock'],
#  ['indie rock', 'power pop'],
#  ['alternative emo',
#   'anthem emo',
#   'modern alternative rock',
#   'neon pop punk',
#   'pop emo',
#   'pop punk'],
#  ['pop punk', 'punk', 'socal pop punk'],
#  ['alternative dance',
#   'alternative rock',
#   'baroque pop',
#   'canadian indie',
#   'canadian rock',
#   'chillwave',
#   'dance-punk',
#   'freak folk',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'modern rock',
#   'nu gaze',
#   'stomp and holler'],
#  ['alternative rock',
#   'art rock',
#   'melancholia',
#   'oxford indie',
#   'permanent wave',
#   'rock'],
#  ['dance pop', 'pop', 'urban contemporary'],
#  ['dance pop', 'pop', 'urban contemporary'],
#  ['alternative rock', 'indie pop', 'indie rock', 'modern rock'],
#  ['freak folk',
#   'indie garage rock',
#   'indie rock',
#   'indie surf',
#   'neo-psychedelic',
#   'noise pop'],
#  ['freak folk',
#   'indie garage rock',
#   'indie rock',
#   'indie surf',
#   'neo-psychedelic',
#   'noise pop'],
#  ['freak folk',
#   'indie garage rock',
#   'indie rock',
#   'indie surf',
#   'neo-psychedelic',
#   'noise pop'],
#  ['pop', 'post-teen pop'],
#  ['alternative metal',
#   'alternative rock',
#   'blues rock',
#   'modern rock',
#   'nu metal',
#   'palm desert scene',
#   'rock',
#   'stoner metal',
#   'stoner rock'],
#  ['alternative rock',
#   'modern power pop',
#   'modern rock',
#   'permanent wave',
#   'pop rock',
#   'rock'],
#  ['pop', 'post-teen pop'],
#  ['irish singer-songwriter', 'modern rock', 'pop'],
#  ['dance pop', 'edm', 'pop', 'pop dance'],
#  ['dance pop', 'edm', 'pop', 'pop dance'],
#  ['neo soul', 'pop', 'pop soul', 'r&b', 'urban contemporary'],
#  ['pop rap'],
#  ['dance pop', 'pop'],
#  ['dance pop', 'pop'],
#  ['dance pop', 'neo soul', 'pop'],
#  ['dance pop',
#   'dance rock',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop rock',
#   'rock'],
#  ['reggae fusion'],
#  ['dance pop',
#   'edm',
#   'pop',
#   'pop dance',
#   'post-teen pop',
#   'tropical house',
#   'uk dance',
#   'uk funky'],
#  ['dance pop',
#   'edm',
#   'pop',
#   'pop dance',
#   'post-teen pop',
#   'tropical house',
#   'uk dance',
#   'uk funky'],
#  ['modern alternative rock',
#   'modern rock',
#   'neon pop punk',
#   'pop emo',
#   'pop punk',
#   'rock'],
#  ['dance pop', 'hip pop', 'pop', 'post-teen pop'],
#  ['dance pop', 'pop rap'],
#  ['dance pop', 'hip pop', 'pop', 'post-teen pop'],
#  ['reggae fusion'],
#  ['australian dance', 'australian pop', 'pop'],
#  ['detroit hip hop', 'hip hop', 'rap'],
#  ['dance pop', 'edm', 'pop', 'pop dance'],
#  ['north carolina hip hop', 'rap'],
#  ['folk-pop',
#   'modern rock',
#   'neo mellow',
#   'neo-singer-songwriter',
#   'pop',
#   'pop rock'],
#  ['modern rock', 'rock'],
#  ['modern rock', 'rock'],
#  ['modern rock', 'rock'],
#  ['modern rock', 'rock'],
#  ['modern rock', 'rock'],
#  ['dance pop', 'piano rock', 'pop', 'pop rock', 'post-teen pop'],
#  ['dance pop',
#   'modern rock',
#   'neo mellow',
#   'pop',
#   'pop rock',
#   'post-teen pop'],
#  ['british soul', 'pop', 'pop soul', 'uk pop'],
#  ['british soul', 'pop', 'pop soul', 'uk pop'],
#  ['brostep',
#   'dance pop',
#   'edm',
#   'pop',
#   'pop dance',
#   'progressive electro house'],
#  ['indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop',
#   'pop rock'],
#  ['baroque pop', 'emo', 'modern rock'],
#  ['pop', 'uk pop'],
#  ['pop', 'uk pop'],
#  ['double drumming',
#   'indie pop',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop',
#   'pop rock',
#   'stomp and holler'],
#  ['double drumming',
#   'indie pop',
#   'indie poptimism',
#   'modern alternative rock',
#   'modern rock',
#   'pop',
#   'pop rock',
#   'stomp and holler'],
#  ['dance pop',
#   'edm',
#   'pop',
#   'pop dance',
#   'post-teen pop',
#   'tropical house',
#   'uk dance',
#   'uk funky'],
#  ['anthem worship',
#   'ccm',
#   'christian alternative rock',
#   'christian music',
#   'christian pop',
#   'worship'],
#  ['dance pop', 'modern rock', 'pop', 'pop rap', 'seattle hip hop'],
#  ['australian indie', 'australian pop', 'folk-pop', 'modern rock', 'pop rock'],
#  ['emo', 'modern rock', 'pop punk'],
#  ...]

# %%
long_set_of_songs['genres'] = long_genres

# %%
long_set_of_songs
# Out:
#                                             name  \
# 0     Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                          Toxic
# 2                    Crazy In Love (feat. Jay-Z)
# 3                                 Rock Your Body
# 4                                   It Wasn't Me
# ...                                          ...
# 6094  Midnight Train to Georgia - Single Version
# 6095                                    My Thang
# 6096                               Pass The Peas
# 6097                    Laisse tomber les filles
# 6098                     Theme for the Lime Cafe
#
#                                              album                    artist  \
# 0                                     The Cookbook             Missy Elliott
# 1                                      In The Zone            Britney Spears
# 2     Dangerously In Love (Alben für die Ewigkeit)                   Beyoncé
# 3                                        Justified         Justin Timberlake
# 4              Hot Shot (International Version #2)                    Shaggy
# ...                                            ...                       ...
# 6094                Imagination (Expanded Edition)  Gladys Knight & The Pips
# 6095                                          Hell               James Brown
# 6096                    James Brown's Funky People           Various Artists
# 6097                                Paris in April               April March
# 6098                    April March and Los Cincos               April March
#
#      release_date  length  popularity  danceability  energy  key  loudness  \
# 0      2005-07-04  226863          67         0.904   0.813    4    -7.105
# 1      2003-11-13  198800          82         0.774   0.838    5    -3.914
# 2      2003-06-23  235933          23         0.664   0.758    2    -6.583
# 3      2002-11-04  267266          76         0.892   0.714    4    -6.055
# 4            2000  227600           0         0.853   0.606    0    -4.596
# ...           ...     ...         ...           ...     ...  ...       ...
# 6094         1973  237120          37         0.570   0.438   10    -9.928
# 6095   1974-01-01  259760           0         0.523   0.743    1   -10.760
# 6096   1986-01-01  192160           0         0.561   0.311    2   -14.981
# 6097         1996  127280           0         0.606   0.949    4    -4.324
# 6098   2012-02-14  184133           0         0.480   0.522    0    -8.892
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        0       0.1210       0.03110          0.006970    0.0471    0.810
# 1        0       0.1140       0.02490          0.025000    0.2420    0.924
# 2        0       0.2100       0.00238          0.000000    0.0598    0.701
# 3        0       0.1410       0.20100          0.000234    0.0521    0.817
# 4        1       0.0713       0.05610          0.000000    0.3130    0.654
# ...    ...          ...           ...               ...       ...      ...
# 6094     0       0.0404       0.18900          0.000006    0.1010    0.425
# 6095     1       0.2400       0.04370          0.000000    0.3220    0.648
# 6096     1       0.2650       0.26000          0.000237    0.3530    0.702
# 6097     1       0.0461       0.47300          0.000000    0.3840    0.906
# 6098     0       0.0272       0.45700          0.001550    0.1150    0.258
#
#         tempo  time_signature  \
# 0     125.461               4
# 1     143.040               4
# 2      99.259               4
# 3     100.972               4
# 4      94.759               4
# ...       ...             ...
# 6094   89.246               4
# 6095  202.607               4
# 6096  195.996               4
# 6097  139.121               4
# 6098  139.667               4
#
#                                                  genres
# 0     [dance pop, hip pop, pop, post-teen pop, r&b, ...
# 1                       [dance pop, pop, post-teen pop]
# 2               [houston rap, pop, pop rap, trap queen]
# 3                                      [dance pop, pop]
# 4                   [dance pop, pop rap, reggae fusion]
# ...                                                 ...
# 6094  [brill building pop, classic soul, disco, funk...
# 6095  [bass house, edm, electro house, house, pop da...
# 6096  [classic rock, folk, folk rock, mellow gold, r...
# 6097                                                 []
# 6098                                                 []
#
# [6099 rows x 19 columns]

# %%
long_set_of_songs.to_csv(r'C:\Users\ecusa\OneDrive\Desktop\MPSD\long_set_of_songs.csv')

# %%
#drop irrelevant features, run knn model
ml_features_for_long_set_of_songs = getRelevantData(user_playlist, long_set_of_songs)

# %%
ml_features_for_long_set_of_songs
# Out:
#                                             name  \
# 0     Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                          Toxic
# 2                    Crazy In Love (feat. Jay-Z)
# 3                                 Rock Your Body
# 4                                   It Wasn't Me
# ...                                          ...
# 6054                               Big Eyed Fish
# 6055                                     Captain
# 6056                                Busted Stuff
# 6058         The Love You Save (May Be Your Own)
# 6066                     Gloria - Stereo Version
#
#                                              album              artist  \
# 0                                     The Cookbook       Missy Elliott
# 1                                      In The Zone      Britney Spears
# 2     Dangerously In Love (Alben für die Ewigkeit)             Beyoncé
# 3                                        Justified   Justin Timberlake
# 4              Hot Shot (International Version #2)              Shaggy
# ...                                            ...                 ...
# 6054                                  Busted Stuff  Dave Matthews Band
# 6055                                  Busted Stuff  Dave Matthews Band
# 6056                                  Busted Stuff  Dave Matthews Band
# 6058                                 Greatest Hits             Joe Tex
# 6066                  Gold (International Version)                Them
#
#      release_date  length  popularity  danceability  energy  key  loudness  \
# 0      2005-07-04  226863          67         0.904   0.813    4    -7.105
# 1      2003-11-13  198800          82         0.774   0.838    5    -3.914
# 2      2003-06-23  235933          23         0.664   0.758    2    -6.583
# 3      2002-11-04  267266          76         0.892   0.714    4    -6.055
# 4            2000  227600           0         0.853   0.606    0    -4.596
# ...           ...     ...         ...           ...     ...  ...       ...
# 6054   2002-07-16  304493          43         0.516   0.584    7    -6.452
# 6055   2002-07-16  225506          32         0.594   0.797    9    -8.711
# 6056   2002-07-16  227106          41         0.556   0.657    7    -5.319
# 6058   2000-11-06  174779          38         0.502   0.300   10   -13.698
# 6066   2005-01-01  156106           0         0.646   0.813    9    -6.733
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        0       0.1210       0.03110          0.006970    0.0471    0.810
# 1        0       0.1140       0.02490          0.025000    0.2420    0.924
# 2        0       0.2100       0.00238          0.000000    0.0598    0.701
# 3        0       0.1410       0.20100          0.000234    0.0521    0.817
# 4        1       0.0713       0.05610          0.000000    0.3130    0.654
# ...    ...          ...           ...               ...       ...      ...
# 6054     1       0.0264       0.31900          0.000167    0.1840    0.437
# 6055     1       0.0316       0.51400          0.014900    0.1310    0.578
# 6056     1       0.0422       0.40300          0.009470    0.5850    0.655
# 6058     1       0.0372       0.77100          0.000000    0.1330    0.453
# 6066     1       0.0434       0.52800          0.007860    0.1780    0.711
#
#         tempo  time_signature  \
# 0     125.461               4
# 1     143.040               4
# 2      99.259               4
# 3     100.972               4
# 4      94.759               4
# ...       ...             ...
# 6054   81.485               4
# 6055   99.613               4
# 6056  171.514               4
# 6058   94.582               3
# 6066  129.378               4
#
#                                                  genres
# 0     [dance pop, hip pop, pop, post-teen pop, r&b, ...
# 1                       [dance pop, pop, post-teen pop]
# 2               [houston rap, pop, pop rap, trap queen]
# 3                                      [dance pop, pop]
# 4                   [dance pop, pop rap, reggae fusion]
# ...                                                 ...
# 6054                   [jam band, neo mellow, pop rock]
# 6055                   [jam band, neo mellow, pop rock]
# 6056                   [jam band, neo mellow, pop rock]
# 6058  [alternative americana, chamber pop, freak fol...
# 6066                [afrofuturism, hip hop, indie soul]
#
# [3259 rows x 19 columns]

# %%
ml_features_for_long_set_of_songs.drop(['name',  'album',  'artist', 'release_date', 'popularity', 'genres'], axis=1, inplace=True)

# %%
long_frequencies_of_recs = recommendationList(ml_features_for_user_playlist, ml_features_for_long_set_of_songs)

# %%
long_sorted_indices = indicesOfMax(long_frequencies_of_recs)
# Out:
# [2644, 51]
# [86, 49]
# [2975, 40]
# [2260, 39]
# [541, 38]
# [2209, 38]
# [1847, 37]
# [1809, 33]
# [2147, 31]
# [750, 29]

# %%
long_set_of_songs.iloc[long_sorted_indices]
# Out:
#                                               name  \
# 2644                           In the Name of Love
# 86                                             YYZ
# 2975  We Found Love (feat. Jess Moskaluke) - Bonus
# 2260                        Sit Still, Look Pretty
# 541                                         Yellow
# 2209                                       Starboy
# 1847                                     Chan Chan
# 1809                                  Twenty Miles
# 2147                                     I'm Yours
# 750                                 Hard To Handle
#
#                                     album                   artist  \
# 2644         The Martin Garrix Collection            Martin Garrix
# 86        Moving Pictures (2011 Remaster)                     Rush
# 2975            Honestly (Deluxe Version)               Tyler Ward
# 2260               Sit Still, Look Pretty                     Daya
# 541                          Good For You                    Aminé
# 2209                              Starboy               The Weeknd
# 1847              Buena Vista Social Club  Buena Vista Social Club
# 1809              The Black Dirt Sessions                Deer Tick
# 2147  We Sing. We Dance. We Steal Things.               Jason Mraz
# 750                Shake Your Money Maker         The Black Crowes
#
#      release_date  length  popularity  danceability  energy  key  loudness  \
# 2644   2017-04-21  195840          21         0.490   0.485    4    -6.237
# 86     1981-02-12  265840          57         0.510   0.919    7    -8.244
# 2975   2013-10-18  187333          35         0.419   0.173    2   -14.715
# 2260   2017-01-06  202226          62         0.655   0.787    2    -3.031
# 541    2017-07-28  180000          56         0.869   0.526    0    -5.766
# 2209   2016-11-25  230453           1         0.681   0.594    7    -7.028
# 1847   1997-09-16  257737           0         0.506   0.433    2   -14.183
# 1809   2010-06-09  223933          47         0.501   0.784    0    -7.089
# 2147   2008-05-01  242186          72         0.686   0.457   11    -8.322
# 750    1990-01-01  188066           0         0.591   0.790    4    -3.597
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 2644     0       0.0406       0.05920          0.000000     0.337    0.196
# 86       1       0.0593       0.00205          0.809000     0.068    0.386
# 2975     0       0.0391       0.86600          0.000000     0.157    0.336
# 2260     1       0.2640       0.12200          0.000003     0.178    0.554
# 541      1       0.1110       0.13900          0.000000     0.119    0.217
# 2209     1       0.2820       0.16500          0.000003     0.134    0.535
# 1847     0       0.0345       0.84200          0.031100     0.112    0.641
# 1809     1       0.0334       0.52900          0.076600     0.131    0.340
# 2147     1       0.0468       0.59500          0.000000     0.105    0.718
# 750      1       0.0432       0.00224          0.000886     0.292    0.961
#
#         tempo  time_signature  \
# 2644  133.889               4
# 86    141.053               4
# 2975   99.149               4
# 2260  181.799               4
# 541   128.996               4
# 2209  186.054               4
# 1847   83.222               4
# 1809  113.643               4
# 2147  150.953               4
# 750   104.171               4
#
#                                                  genres
# 2644  [dance pop, dutch edm, edm, electro house, pop...
# 86    [australian dance, australian electropop, aust...
# 2975  [channel pop, indie cafe pop, neo mellow, vira...
# 2260  [dance pop, edm, electropop, pop, pop dance, t...
# 541   [hip hop, pop rap, portland hip hop, rap, unde...
# 2209     [canadian contemporary r&b, canadian pop, pop]
# 1847     [latin jazz, musica tradicional cubana, world]
# 1809  [alternative country, deep new americana, indi...
# 2147  [acoustic pop, neo mellow, pop, pop rock, vira...
# 750   [album rock, alternative rock, blues rock, cla...
